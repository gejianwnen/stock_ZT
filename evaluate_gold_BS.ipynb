# %%
import time
import datetime
import os
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import tushare as ts
ts.set_token('29eaf3bcac23df4c6d025de157ab2d53beead3391fbe6e83b4ebcb6c')
pro = ts.pro_api()

import mpl_finance as mpf
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib.pylab import date2num
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import seaborn as sns
sns.set()
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'SimHei'
# Out:
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\mpl_finance.py:22: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   category=DeprecationWarning)

# %%
from mylab.stock.myread import getStock
from mylab.stock.myread import getIndex
from mylab.stock.myread import getIndexBasic
from mylab.stock.myread import getStockBasic
from mylab.stock.myread import readData
from mylab.stock.myread import mergeDailyWeeklyMonthly
from mylab.stock.myread import mergeStockIndex
from mylab.stock.myread import getIndustry

from mylab.stock.myfeature import getMacd
from mylab.stock.myfeature import getKdj
from mylab.stock.myfeature import getMa

from mylab.stock.myplot import plotVol
from mylab.stock.myplot import plotCandle
from mylab.stock.myplot import plotMacd
from mylab.stock.myplot import plotKdj

from mylab.stock.mygoldBS import getGoldBS
from mylab.stock.mygoldBS import plotStock
from mylab.stock.mygoldBS import plotGoldBS
from mylab.stock.mygoldBS import displaySelect

# %%
SAVE_CSV = True
LOCAL = not True

GET_DAILY = True
SELECT_STOCK = True

start_date = "20160101"
end_date = "20200413"

# %% [markdown]
# # get all Stocks Info

# %%
#获取基础信息数据，包括股票代码、名称、上市日期、退市日期等

pool_df = getStockBasic(LOCAL = True)
# pool_df = pd.read_csv("./data/stock/blue_stock_rank_3.csv" )


print('获得上市股票总数：', len(pool_df)-1)
pool_df.head()
# Out:
# 获得上市股票总数： 3796
#      ts_code  symbol  name area industry market  list_date
# 0  000001.SZ       1  平安银行   深圳       银行     主板   19910403
# 1  000002.SZ       2   万科A   深圳     全国地产     主板   19910129
# 2  000004.SZ       4  国农科技   深圳     生物制药     主板   19910114
# 3  000005.SZ       5  世纪星源   深圳     环境保护     主板   19901210
# 4  000006.SZ       6  深振业A   深圳     区域地产     主板   19920427

# %% [markdown]
# # try

# %%
start_date = "20180101"
# end_date = "20200101"
stock_code = "002497.SZ"
save_dir = "./output/select_by_gold_BS/"

stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
stock_df = getGoldBS(stock_df)
stock_df = stock_df.loc[240:,:]
plotStock(stock_df ,SAVE = False, save_dir =save_dir)
# Out:
# 0

# %% [markdown]
# # save all stocks in gold BS state

# %%
def selectStockByGoldBS(df):
    select_num = np.any( [stock_df.boom.values>0,
                          stock_df.sell_short.values>0 ,
                         ],
                        axis = 0)   # IF( CROSS(xx,yy) AND xx<20 ,30,0);
    select_df = stock_df.loc[select_num,:]
    return select_df

# %%
start_date = "20100101"
# end_date = "20200101"
stock_code = "002497.SZ"
save_dir = "./output/select_by_gold_BS/all_gold_BS/"

for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    try:
        stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
        stock_df = getGoldBS(stock_df)
        stock_df = stock_df.loc[240:,:]
        select_df = selectStockByGoldBS(stock_df )  # stock  
        select_df = select_df.reset_index()
        select_df = select_df.loc[1:,:]
        select_df.rename(columns = {"index":"pre_index"}, inplace = True)
        select_df.to_csv(save_dir+stock_code+".csv", index = False)
    except Exception as err:
        print(stock_code,stock_name,err)
    
print(select_df.shape)
select_df.head()
# Out:
# 002977.SZ 天箭科技 local variable 'daily_df' referenced before assignment
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b4f5beadc7da> in <module>
#       8     stock_name = pool_df.loc[i,"name"]
#       9     try:
# ---> 10         stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
#      11         stock_df = getGoldBS(stock_df)
#      12         stock_df = stock_df.loc[240:,:]
#
# G:\jupyter-notebook\eastmoney_stock\mylab\stock\myread.py in getStock(stock_code, start_date, end_date, LOCAL)
#     179
#     180 def getStock(stock_code,start_date, end_date  , LOCAL = True):
# --> 181     daily_df = getStockDaily(stock_code,start_date, end_date  , LOCAL = True)
#     182     weekly_df = getStockWeekly(stock_code,start_date , end_date  , LOCAL = True)
#     183     monthly_df = getStockMonthly(stock_code,start_date , end_date  , LOCAL = True)
#
# G:\jupyter-notebook\eastmoney_stock\mylab\stock\myread.py in getStockDaily(stock_code, start_date, end_date, LOCAL)
#      71     dir_file = "./data/stock/daily/"
#      72     if LOCAL:
# ---> 73         daily_df = readData(dir_file, stock_code, start_date , end_date )
#      74     else:
#      75         daily_df = pro.daily(ts_code = stock_code,start_date = start_date, end_date = end_date )
#
# G:\jupyter-notebook\eastmoney_stock\mylab\stock\myread.py in readData(dir_file, stock_code, start_date, end_date)
#     130         for i,file_name in enumerate(files):
#     131             if file_name[:9] == stock_code:
# --> 132                 daily_df = pd.read_csv(file_dir+file_name)
#     133                 daily_df["trade_date"] = daily_df["trade_date"].astype("str")
#     134                 daily_df = daily_df.loc[daily_df["trade_date"] >= start_date,:].reset_index(drop=True)
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# KeyboardInterrupt:

# %% [markdown]
# # evaluate the result

# %%
for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    if stock_code[0] == "6":
        break
    if stock_code[0] == "3":
        break
    try:
        stock_df = pd.read_csv(save_dir+stock_code+".csv")
        stock_df["hold_period"] = np.nan
        stock_df["earn_rate"] = np.nan 
        stock_df["earn_rate_max"] = np.nan 
        for i in range(len(stock_df)):
            if stock_df.boom.values[i] > 0:
                for j in range(i,len(stock_df)):
                    if stock_df.sell_short.values[j] > 0:
                        stock_df["earn_rate"][i] = (stock_df.close.values[j]-stock_df.close.values[i])/stock_df.close.values[i]*100
                        stock_df["earn_rate_max"][i] = (stock_df.high.values[j]-stock_df.close.values[i])/stock_df.close.values[i]*100
                        stock_df["hold_period"][i] = (stock_df.pre_index.values[j]-stock_df.pre_index.values[i]) + 1
                        break
        stock_df["earn_rate_per_day"] = stock_df["earn_rate"]/stock_df["hold_period"]
        stock_df["win"] = stock_df["earn_rate"] > 0
        stock_df.to_csv(save_dir+stock_code+".csv", index = False)
    except Exception as err:
        print(stock_code,stock_name,err)
print(stock_df.shape)
stock_df.head()
# Out:
# 002977.SZ 天箭科技 [Errno 2] File ./output/select_by_gold_BS/all_gold_BS/002977.SZ.csv does not exist: './output/select_by_gold_BS/all_gold_BS/002977.SZ.csv'
# (0, 97)
# Empty DataFrame
# Columns: [pre_index, ts_code, trade_date, open, high, low, close, pre_close, change, pct_chg, vol, amount, trade_date_stamp, K, D, J, kdj_signal, sema, lema, dif, dea, macd, macd_signal, close_weekly, open_weekly, high_weekly, low_weekly, pre_close_weekly, change_weekly, pct_chg_weekly, vol_weekly, amount_weekly, K_weekly, D_weekly, J_weekly, kdj_signal_weekly, sema_weekly, lema_weekly, dif_weekly, dea_weekly, macd_weekly, macd_signal_weekly, close_monthly, open_monthly, high_monthly, low_monthly, pre_close_monthly, change_monthly, pct_chg_monthly, vol_monthly, amount_monthly, K_monthly, D_monthly, J_monthly, kdj_signal_monthly, sema_monthly, lema_monthly, dif_monthly, dea_monthly, macd_monthly, macd_signal_monthly, AA, BB, AAxvol, pre_AA, AA_rise, CC, DD, A1, A2, A3, A4, short, B1, B2, B3, B4, mid, C1, C2, C3, C4, long, sell_goldBS, buy_goldBS, D1, cross_signal, D2, D3, boom, climax, sell_short, hold_period, earn_rate, earn_rate_max, earn_rate_per_day, win]
# Index: []
#
# [0 rows x 97 columns]

# %%
all_df = pool_df.copy(deep = True)
all_df["win_rate"] = np.nan
all_df["earn_rate_per_day"] = np.nan
all_df["earn_rate"] = np.nan
all_df["hold_period"] = np.nan
all_df["num_gold_BS"] = np.nan

for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    if stock_code[0] == "6":
        break
    if stock_code[0] == "3":
        break
    try:
        stock_df = pd.read_csv(save_dir+stock_code+".csv")
        stock_df = stock_df.loc[stock_df.boom.values>0,:]
        if len(stock_df) > 10 :
            all_df["win_rate"][i]  = sum(stock_df["win"].values)/len(stock_df)
            all_df["earn_rate_per_day"][i]  = sum(stock_df["earn_rate_per_day"].values)/len(stock_df)
            all_df["earn_rate"][i]  = sum(stock_df["earn_rate"].values)/len(stock_df)
            all_df["hold_period"][i]  = sum(stock_df["hold_period"].values)/len(stock_df)
            all_df["num_gold_BS"][i] = len(stock_df)
       
    except Exception as err:
        print(stock_code,stock_name,err)
# all_df = all_df.loc[:1402,:]
all_df.to_csv("./output/"+"stocks_statistic_analyse_gold_BS.csv", index = False)
print(all_df.shape)
all_df.head()
# Out:
# 002977.SZ 天箭科技 [Errno 2] File ./output/select_by_gold_BS/all_gold_BS/002977.SZ.csv does not exist: './output/select_by_gold_BS/all_gold_BS/002977.SZ.csv'
# (3797, 12)
#      ts_code  symbol  name area industry market  list_date  win_rate  \
# 0  000001.SZ       1  平安银行   深圳       银行     主板   19910403  0.714286
# 1  000002.SZ       2   万科A   深圳     全国地产     主板   19910129  0.928571
# 2  000004.SZ       4  国农科技   深圳     生物制药     主板   19910114  0.666667
# 3  000005.SZ       5  世纪星源   深圳     环境保护     主板   19901210  0.733333
# 4  000006.SZ       6  深振业A   深圳     区域地产     主板   19920427  0.733333
#
#    earn_rate_per_day  earn_rate  hold_period  num_gold_BS
# 0                NaN        NaN          NaN         14.0
# 1           0.660073   6.105933    17.000000         14.0
# 2           0.675119   2.784303    19.750000         12.0
# 3           0.248871   1.536752    22.566667         30.0
# 4           0.693712   5.826745    18.600000         15.0

# %%
all_df = pd.read_csv("./output/"+"stocks_statistic_analyse_gold_BS.csv")
# all_df = all_df.loc[all_df["hold_period"].values < 12,:]
all_df.win_rate.hist(bins = 20)

# %%
all_df = pd.read_csv("./output/"+"stocks_statistic_analyse_gold_BS.csv")
# earn_rate_per_day earn_rate hold_period num_gold_BS
all_df = all_df.loc[all_df["win_rate"].values > 0.55,:]
all_df = all_df.loc[all_df["earn_rate_per_day"].values > 0.3,:]
all_df = all_df.loc[all_df["earn_rate"].values > 1,:]
all_df = all_df.loc[all_df["hold_period"].values < 30,:]
all_df = all_df.loc[all_df["num_gold_BS"].values > 15,:]
# all_df = all_df.loc[all_df["num_gold_BS"].values < 50,:]
all_df.to_csv("./output/"+"stocks_statistic_analyse_rank1.csv", index = False)
print(all_df.shape)
all_df.hold_period.hist(bins = 20)
# Out:
# (367, 12)

# %%
all_df = pd.read_csv("./output/"+"stocks_statistic_analyse_gold_BS.csv")
# earn_rate_per_day earn_rate hold_period num_gold_BS
all_df = all_df.loc[all_df["win_rate"].values > 0.6,:]
all_df = all_df.loc[all_df["earn_rate_per_day"].values > 0.4,:]
all_df = all_df.loc[all_df["earn_rate"].values > 3,:]
all_df = all_df.loc[all_df["hold_period"].values < 30,:]
all_df = all_df.loc[all_df["num_gold_BS"].values > 15,:]
# all_df = all_df.loc[all_df["num_gold_BS"].values < 50,:]
# all_df = all_df.loc[all_df["num_gold_BS"].values < 50,:]
all_df.to_csv("./output/"+"stocks_statistic_analyse_rank2.csv", index = False)
print(all_df.shape)
all_df.hold_period.hist(bins = 20)
# Out:
# (200, 12)

# %%
all_df = pd.read_csv("./output/"+"stocks_statistic_analyse_gold_BS.csv")
# earn_rate_per_day earn_rate hold_period num_gold_BS
all_df = all_df.loc[all_df["win_rate"].values > 0.7,:]
all_df = all_df.loc[all_df["earn_rate_per_day"].values > 0.4,:]
all_df = all_df.loc[all_df["earn_rate"].values > 5,:]
all_df = all_df.loc[all_df["hold_period"].values < 30,:]
all_df = all_df.loc[all_df["num_gold_BS"].values > 15,:]
# all_df = all_df.loc[all_df["num_gold_BS"].values < 50,:]
all_df.to_csv("./output/"+"stocks_statistic_analyse_rank3.csv", index = False)
print(all_df.shape)
all_df.earn_rate_per_day.hist(bins = 20)
# Out:
# (66, 12)

# %% [markdown]
# # select stocks by gold BS

# %%
def selectStockByGoldBS(df):
    select_df = stock_df.loc[stock_df.boom.values>0,:]
    return select_df

# %%
pool_df.shape
# Out:
# (3797, 7)

# %%
start_date = "20190101"
# end_date = "20200323"
print("end date: ",end_date)

all_select_df = pd.DataFrame()
err_num = 0
for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    if stock_code[0] == "0":
        try:
            stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
            stock_df = getGoldBS(stock_df)
            stock_df = stock_df.loc[240:,:]
            select_df = selectStockByGoldBS(stock_df )  # stock         
        except Exception as err:
            err_num = err_num +1
            print(stock_code,stock_name,err)
            pass
        if len(select_df) > 0:  
            all_select_df  = pd.concat([all_select_df,select_df],axis = 0)
print("num of err：",err_num)
all_select_df.to_csv("./output/"+"stock_selected_by_gold_BS.csv", index = False)
print(all_select_df.shape)
print("end date: ",end_date)
all_select_df = all_select_df.loc[all_select_df["trade_date"] == end_date,:]
stocks_code = all_select_df.ts_code.values
print(all_select_df.shape)
all_select_df.head()
# Out:
# end date:  20200413
# num of err： 1
# (1711, 91)
# end date:  20200413
# (0, 91)
# Empty DataFrame
# Columns: [ts_code, trade_date, open, high, low, close, pre_close, change, pct_chg, vol, amount, trade_date_stamp, K, D, J, kdj_signal, sema, lema, dif, dea, macd, macd_signal, close_weekly, open_weekly, high_weekly, low_weekly, pre_close_weekly, change_weekly, pct_chg_weekly, vol_weekly, amount_weekly, K_weekly, D_weekly, J_weekly, kdj_signal_weekly, sema_weekly, lema_weekly, dif_weekly, dea_weekly, macd_weekly, macd_signal_weekly, close_monthly, open_monthly, high_monthly, low_monthly, pre_close_monthly, change_monthly, pct_chg_monthly, vol_monthly, amount_monthly, K_monthly, D_monthly, J_monthly, kdj_signal_monthly, sema_monthly, lema_monthly, dif_monthly, dea_monthly, macd_monthly, macd_signal_monthly, AA, BB, AAxvol, pre_AA, AA_rise, CC, DD, A1, A2, A3, A4, short, B1, B2, B3, B4, mid, C1, C2, C3, C4, long, sell_goldBS, buy_goldBS, D1, cross_signal, D2, D3, boom, climax, sell_short]
# Index: []
#
# [0 rows x 91 columns]

# %%
# all_select_df.to_csv("./output/"+"stock_selected_by_gold_BS.csv", index = False)
all_select_df = pd.read_csv("./output/"+"stock_selected_by_gold_BS.csv")
all_select_df["trade_date"] = all_select_df["trade_date"].astype(str)
print(all_select_df.shape)
print("end date: ",end_date)
# all_select_df = all_select_df.loc[all_select_df["trade_date"] == end_date,:]
all_select_df.to_csv("./output/"+"stock_selected_by_gold_BS_"+end_date+".csv", index = False)
stocks_code = all_select_df.ts_code.values
print(all_select_df.shape)
all_select_df.head()

# %%
save_dir = "./output/select_by_gold_BS/"
start_date = "20140101"
# end_date = "20200323"

# all_select_df = pd.read_csv("./output/"+"stock_selected_by_industry_KDJ.csv")
# stocks_code = ["002497.SZ"]  # stock 
for stock_code in stocks_code:
    stock_df = getStock(stock_code,start_date, end_date , LOCAL = True)
    stock_df = getGoldBS(stock_df)
    select_df = selectStockByGoldBS(stock_df )  # stock 
    print(stock_code,len(select_df))
    for i in range(len(select_df)):
        ix = select_df.index[i]
        trade_date = select_df.trade_date.values[i]
        display_df = displaySelect(stock_df,ix, trade_date= trade_date, save_dir = save_dir )
        plt.close()
