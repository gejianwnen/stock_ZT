# %%
import time
import datetime
import os
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import tushare as ts
ts.set_token('29eaf3bcac23df4c6d025de157ab2d53beead3391fbe6e83b4ebcb6c')
pro = ts.pro_api()

import mpl_finance as mpf
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib.pylab import date2num
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import seaborn as sns
sns.set()
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'SimHei'

# %%
from mylab.stock.myread import getStock
from mylab.stock.myread import getIndex
from mylab.stock.myread import getIndexBasic
from mylab.stock.myread import getStockBasic
from mylab.stock.myread import readData
from mylab.stock.myread import mergeDailyWeeklyMonthly
from mylab.stock.myread import mergeStockIndex
from mylab.stock.myread import getIndustry
from mylab.stock.myread import deleteSTKC

from mylab.stock.myfeature import getMacd
from mylab.stock.myfeature import getKdj
from mylab.stock.myfeature import getMa

from mylab.stock.myplot import plotVol
from mylab.stock.myplot import plotCandle
from mylab.stock.myplot import plotMacd
from mylab.stock.myplot import plotKdj

from mylab.stock.my3point import get3Percent
from mylab.stock.my3point import plotStock
from mylab.stock.my3point import plot3Percent
from mylab.stock.my3point import displaySelect

# %%
SAVE_CSV = True
LOCAL = not True

GET_DAILY = True
SELECT_STOCK = True

start_date = "20160101"
end_date = "20200413"

# %% [markdown]
# # get all Stocks Info

# %%
#获取基础信息数据，包括股票代码、名称、上市日期、退市日期等

pool_df = getStockBasic(LOCAL = False,noSTKC = True, list_data = "20180101")
# pool_df = pd.read_csv("./data/stock/blue_stock_rank_3.csv" )

print('获得上市股票总数：', len(pool_df)-1)
pool_df.head()
# Out:
# 获得上市股票总数： 2640
#      ts_code  symbol  name area industry market exchange list_status  \
# 0  000001.SZ  000001  平安银行   深圳       银行     主板     SZSE           L
# 1  000002.SZ  000002   万科A   深圳     全国地产     主板     SZSE           L
# 2  000004.SZ  000004  国农科技   深圳     生物制药     主板     SZSE           L
# 3  000005.SZ  000005  世纪星源   深圳     环境保护     主板     SZSE           L
# 4  000006.SZ  000006  深振业A   深圳     区域地产     主板     SZSE           L
#
#   list_date delist_date
# 0  19910403        None
# 1  19910129        None
# 2  19910114        None
# 3  19901210        None
# 4  19920427        None

# %% [markdown]
# # plot demo

# %%
start_date = "20190901"
# end_date = "20200101"
stock_code = "000001.SZ"
save_dir = "./output/select_by_3_percent/"

stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
stock_df = get3Percent(stock_df)
plotStock(stock_df ,SAVE = False, save_dir =save_dir)
# Out:
# 0

# %% [markdown]
# # save all stocks in 3% state

# %%
def selectStockBy3Percent(df):
    select_num = np.any( [stock_df.buy_signal.values>0,
                          stock_df.sell_signal.values>0 ,
                         ],
                        axis = 0)   # IF( CROSS(xx,yy) AND xx<20 ,30,0);
    select_df = stock_df.loc[select_num,:]
    return select_df

# %%
# select all
start_date = "20100101"
# end_date = "20200101"
stock_code = "002499.SZ"
save_dir = "./output/select_by_3_percent/all_3_percent/"

for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    try:
        stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
        stock_df = get3Percent(stock_df)
        select_df = selectStockBy3Percent(stock_df )  # stock  
        select_df = select_df.reset_index()
        select_df = select_df.loc[1:,:]
        select_df.rename(columns = {"index":"pre_index"}, inplace = True)
        select_df.to_csv(save_dir+stock_code+".csv", index = False)
    except Exception as err:
        print(stock_code,stock_name,err)
    
print(select_df.shape)
select_df.head()
# Out:
# 002977.SZ 天箭科技 local variable 'daily_df' referenced before assignment
# 300823.SZ 建科机械 local variable 'daily_df' referenced before assignment
# 603221.SH N爱丽 local variable 'daily_df' referenced before assignment
# 688051.SH 佳华科技 local variable 'daily_df' referenced before assignment
# (4, 68)
#    pre_index    ts_code trade_date   open   high    low  close  pre_close  \
# 1         74  688399.SH   20200327  85.58  85.58  80.11  80.11      83.30
# 2         76  688399.SH   20200331  77.97  78.00  74.26  74.89      77.35
# 3         80  688399.SH   20200407  75.00  78.20  74.68  76.43      73.74
# 4         83  688399.SH   20200410  78.31  81.48  77.83  79.79      77.70
#
#    change  pct_chg  ...  dea_monthly  macd_monthly  macd_signal_monthly  \
# 1   -3.19  -3.8295  ...     0.732392      0.673391                  0.0
# 2   -2.46  -3.1803  ...     0.732392      0.673391                  0.0
# 3    2.69   3.6480  ...     0.732392      0.673391                  0.0
# 4    2.09   2.6898  ...     0.732392      0.673391                  0.0
#
#          var         xx        xx1         yy  cross_signal  buy_signal  \
# 1  30.794424  21.268410  20.208056  19.495105           1.0           0
# 2  10.749076  19.626364  20.614035  20.623235          -1.0           0
# 3  20.812476  16.364636  15.870078  16.148617           0.0          30
# 4  33.471313  20.232953  18.761363  18.183799           1.0           0
#
#    sell_signal
# 1           30
# 2           30
# 3            0
# 4           30
#
# [4 rows x 68 columns]

# %% [markdown]
# # conduct the policy

# %%
def actionDay(stock_df,select_df,buy_day_ix,hold_period):
    stock_ix = select_df.pre_index.values[buy_day_ix] 
    act_day_ix = stock_ix+hold_period
    sell = True
    # reach max
    if stock_df.high.values[ act_day_ix ] > select_df.target_price.values[buy_day_ix]:
        select_df["sell_price"][buy_day_ix] = select_df.target_price.values[buy_day_ix]
        if stock_df.open.values[ act_day_ix ] > select_df.target_price.values[buy_day_ix]:
            select_df["sell_price"][buy_day_ix] = stock_df.open.values[ act_day_ix ]
        select_df["hold_period"][buy_day_ix] = hold_period
        select_df["sell_reason"][buy_day_ix] = "get target profit"
    # reach min
    elif stock_df.low.values[ act_day_ix] < select_df.minimal_price.values[buy_day_ix]:
        select_df["sell_price"][buy_day_ix] = stock_df.close.values[ act_day_ix]
        select_df["hold_period"][buy_day_ix] = hold_period
        select_df["sell_reason"][buy_day_ix] = "get minimal_price profit"
    # get sell signal
    elif stock_df.sell_signal.values[ act_day_ix] > 0:
        select_df["sell_price"][buy_day_ix] = stock_df.close.values[ act_day_ix ] 
        select_df["hold_period"][buy_day_ix] = hold_period
        select_df["sell_reason"][buy_day_ix] = "get sell signal"
    else:
        sell = False
        pass
    
    return select_df,sell
def action3Per(stock_df,select_df,buy_day_ix):
    stock_ix = select_df.pre_index.values[buy_day_ix]
    # day 1
    select_df, sell = actionDay(stock_df,select_df,buy_day_ix,1)
    if not sell:
        select_df, sell = actionDay(stock_df,select_df,buy_day_ix,2)
        if not sell:
            select_df, sell = actionDay(stock_df,select_df,buy_day_ix,3)
            if not sell:
                select_df, sell = actionDay(stock_df,select_df,buy_day_ix,4)
                if not sell:
                    select_df["sell_price"][i] = stock_df.close.values[ stock_ix + 4 ] 
                    select_df["hold_period"][i] = 4
                    select_df["sell_reason"][i] = "get max period"
    return select_df

# %%
# policy
start_date = "20100101"
end_date = "20200413"
# stock_code = "002499.SZ"
save_dir = "./output/select_by_3_percent/reesult_policy1/"

for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    try:
        stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
        stock_df = get3Percent(stock_df)
        # select df 
        select_df = stock_df.loc[stock_df.buy_signal.values>0,:]
        # reindex select df otherwise wrong !!!
        select_df = select_df.iloc[1:-1,:]
        select_df = select_df.reset_index()
        select_df.rename(columns = {"index":"pre_index"}, inplace = True)
#         print(stock_code,stock_name,len(select_df))
    except Exception as err:
        print(stock_code,stock_name,err)
        
    try:
        # initiate columns
        select_df["postday_open"] = np.nan 
        select_df["postday_high"] = np.nan 
        select_df["postday_low"] = np.nan 
        select_df["postday_close"] = np.nan 
        select_df["buy_price"] = np.nan
        select_df["target_price"] = np.nan
        select_df["minimal_price"] = np.nan
        select_df["sell_price"] = np.nan
        select_df["hold_period"] = np.nan
        select_df["sell_reason"] = np.nan 
        for i in select_df.index.values:
            # policy
            stock_ix = select_df.pre_index.values[i] 
            # 15 天以内出现过两次底部突破 才符合条件
            if sum(stock_df.buy_signal.values[stock_ix-15:stock_ix-1]) == 0:
                continue
            # 当天涨停的股票不算
            if select_df.pct_chg.values[i] > 9.7:
                continue
            # save necessary information
            select_df.buy_price.values[i] = stock_df.close.values[stock_ix]
            select_df.target_price.values[i] = stock_df.close.values[stock_ix] *1.03 
            select_df.minimal_price.values[i] = stock_df.close.values[stock_ix] *0.97 
            select_df["postday_open"][i] = stock_df.open.values[stock_ix+1]
            select_df["postday_high"][i] = stock_df.high.values[stock_ix+1]
            select_df["postday_low"][i] = stock_df.low.values[stock_ix+1]
            select_df["postday_close"][i] = stock_df.close.values[stock_ix+1]
            # conduct policy
            select_df = action3Per(stock_df,select_df,i)
            
        # calculate some important inform after all buy-sell points are conducted
        select_df["earn_rate"] = (select_df["sell_price"]/select_df["buy_price"]-1)*100
        select_df["earn_rate_per_day"] = select_df["earn_rate"]/select_df["hold_period"]
        select_df["win"] = select_df["earn_rate"] > 0
        # drop nan and save
        select_df = select_df.dropna()
        if sum(select_df["earn_rate"]>3.1)>0:
            print("earn_rate >3 :",stock_code,stock_name,len(select_df))
        select_df.to_csv(save_dir+stock_code+".csv", index = False)
#         print(stock_code,stock_name,len(select_df))
    except Exception as err:
        print(stock_code,stock_name,err)
print(select_df.shape)
select_df.head(20)
# Out:
# earn_rate >3 : 002765.SZ 蓝黛传动 16
# earn_rate >3 : 002781.SZ 奇信股份 8
# earn_rate >3 : 002789.SZ 建艺集团 5
# earn_rate >3 : 002813.SZ 路畅科技 10
# earn_rate >3 : 002818.SZ 富森美 5
# earn_rate >3 : 002820.SZ 桂发祥 6
# earn_rate >3 : 002824.SZ 和胜股份 7
# earn_rate >3 : 002830.SZ 名雕股份 10
# earn_rate >3 : 002836.SZ 新宏泽 6
# earn_rate >3 : 002848.SZ 高斯贝尔 7
# earn_rate >3 : 002849.SZ 威星智能 6
# earn_rate >3 : 002850.SZ 科达利 14
# earn_rate >3 : 002852.SZ 道道全 16
# earn_rate >3 : 002853.SZ 皮阿诺 15
# earn_rate >3 : 002873.SZ 新天药业 8
# earn_rate >3 : 002890.SZ 弘宇股份 6
# earn_rate >3 : 002891.SZ 中宠股份 6
# earn_rate >3 : 002903.SZ 宇环数控 6
# earn_rate >3 : 002915.SZ 中欣氟材 3
# earn_rate >3 : 002917.SZ 金奥博 6
# earn_rate >3 : 002920.SZ 德赛西威 7
# earn_rate >3 : 002932.SZ 明德生物 6
# 002977.SZ 天箭科技 local variable 'daily_df' referenced before assignment
# 002978.SZ 安宁股份 local variable 'daily_df' referenced before assignment
# 002979.SZ 雷赛智能 local variable 'daily_df' referenced before assignment
# 002980.SZ 华盛昌 local variable 'daily_df' referenced before assignment
# 002981.SZ 朝阳科技 local variable 'daily_df' referenced before assignment
# 002982.SZ 湘佳股份 local variable 'daily_df' referenced before assignment
# 002983.SZ 芯瑞达 local variable 'daily_df' referenced before assignment
# 002985.SZ N北摩 local variable 'daily_df' referenced before assignment
# earn_rate >3 : 600006.SH 东风汽车 25
# earn_rate >3 : 600008.SH 首创股份 28
# earn_rate >3 : 600018.SH 上港集团 25
# earn_rate >3 : 600027.SH 华电国际 23
# earn_rate >3 : 600031.SH 三一重工 13
# earn_rate >3 : 600039.SH 四川路桥 12
# earn_rate >3 : 600053.SH 九鼎投资 25
# earn_rate >3 : 600055.SH 万东医疗 17
# earn_rate >3 : 600063.SH 皖维高新 21
# earn_rate >3 : 600066.SH 宇通客车 15
# earn_rate >3 : 600068.SH 葛洲坝 20
# earn_rate >3 : 600070.SH 浙江富润 26
# earn_rate >3 : 600078.SH 澄星股份 32
# earn_rate >3 : 600091.SH ST明科 16
# earn_rate >3 : 600095.SH 哈高科 27
# earn_rate >3 : 600098.SH 广州发展 23
# earn_rate >3 : 600105.SH 永鼎股份 20
# earn_rate >3 : 600106.SH 重庆路桥 22
# earn_rate >3 : 600107.SH 美尔雅 31
# earn_rate >3 : 600111.SH 北方稀土 19
# earn_rate >3 : 600115.SH 东方航空 26
# earn_rate >3 : 600116.SH 三峡水利 17
# earn_rate >3 : 600117.SH 西宁特钢 25
# earn_rate >3 : 600120.SH 浙江东方 23
# earn_rate >3 : 600125.SH 铁龙物流 15
# earn_rate >3 : 600128.SH 弘业股份 22
# earn_rate >3 : 600133.SH 东湖高新 21
# earn_rate >3 : 600141.SH 兴发集团 23
# earn_rate >3 : 600151.SH 航天机电 19
# earn_rate >3 : 600152.SH 维科技术 16
# earn_rate >3 : 600157.SH 永泰能源 23
# earn_rate >3 : 600160.SH 巨化股份 16
# earn_rate >3 : 600162.SH 香江控股 24
# earn_rate >3 : 600177.SH 雅戈尔 27
# earn_rate >3 : 600182.SH S佳通 10
# earn_rate >3 : 600186.SH 莲花健康 17
# earn_rate >3 : 600189.SH 吉林森工 24
# earn_rate >3 : 600191.SH 华资实业 23
# earn_rate >3 : 600192.SH 长城电工 19
# earn_rate >3 : 600195.SH 中牧股份 6
# earn_rate >3 : 600207.SH 安彩高科 19
# earn_rate >3 : 600209.SH ST罗顿 22
# earn_rate >3 : 600211.SH 西藏药业 10
# earn_rate >3 : 600216.SH 浙江医药 9
# earn_rate >3 : 600217.SH 中再资环 22
# earn_rate >3 : 600228.SH ST昌九 15
# earn_rate >3 : 600236.SH 桂冠电力 13
# earn_rate >3 : 600238.SH ST椰岛 15
# earn_rate >3 : 600242.SH 中昌数据 14
# earn_rate >3 : 600247.SH ST成城 17
# earn_rate >3 : 600249.SH 两面针 18
# earn_rate >3 : 600250.SH 南纺股份 13
# earn_rate >3 : 600257.SH 大湖股份 20
# earn_rate >3 : 600259.SH 广晟有色 20
# earn_rate >3 : 600260.SH 凯乐科技 12
# earn_rate >3 : 600266.SH 城建发展 19
# earn_rate >3 : 600268.SH 国电南自 18
# earn_rate >3 : 600275.SH ST昌鱼 13
# earn_rate >3 : 600276.SH 恒瑞医药 9
# earn_rate >3 : 600278.SH 东方创业 19
# earn_rate >3 : 600287.SH 江苏舜天 16
# earn_rate >3 : 600288.SH 大恒科技 19
# earn_rate >3 : 600291.SH 西水股份 19
# earn_rate >3 : 600293.SH 三峡新材 17
# earn_rate >3 : 600295.SH 鄂尔多斯 26
# earn_rate >3 : 600303.SH 曙光股份 26
# earn_rate >3 : 600316.SH 洪都航空 18
# earn_rate >3 : 600317.SH 营口港 18
# earn_rate >3 : 600338.SH 西藏珠峰 13
# earn_rate >3 : 600350.SH 山东高速 22
# earn_rate >3 : 600355.SH 精伦电子 9
# earn_rate >3 : 600358.SH 国旅联合 16
# earn_rate >3 : 600362.SH 江西铜业 34
# earn_rate >3 : 600366.SH 宁波韵升 23
# earn_rate >3 : 600379.SH 宝光股份 13
# earn_rate >3 : 600381.SH 青海春天 15
# earn_rate >3 : 600382.SH 广东明珠 24
# earn_rate >3 : 600387.SH 海越能源 22
# earn_rate >3 : 600396.SH 金山股份 20
# earn_rate >3 : 600398.SH 海澜之家 14
# earn_rate >3 : 600399.SH ST抚钢 15
# earn_rate >3 : 600400.SH 红豆股份 26
# earn_rate >3 : 600406.SH 国电南瑞 14
# earn_rate >3 : 600408.SH ST安泰 24
# earn_rate >3 : 600409.SH 三友化工 17
# earn_rate >3 : 600418.SH 江淮汽车 22
# earn_rate >3 : 600422.SH 昆药集团 13
# earn_rate >3 : 600428.SH 中远海特 22
# earn_rate >3 : 600433.SH 冠豪高新 21
# earn_rate >3 : 600438.SH 通威股份 14
# earn_rate >3 : 600446.SH 金证股份 17
# earn_rate >3 : 600466.SH 蓝光发展 13
# earn_rate >3 : 600476.SH 湘邮科技 15
# earn_rate >3 : 600478.SH 科力远 7
# earn_rate >3 : 600481.SH 双良节能 25
# earn_rate >3 : 600487.SH 亨通光电 11
# earn_rate >3 : 600489.SH 中金黄金 32
# earn_rate >3 : 600491.SH 龙元建设 24
# earn_rate >3 : 600493.SH 凤竹纺织 17
# earn_rate >3 : 600496.SH 精工钢构 27
# earn_rate >3 : 600497.SH 驰宏锌锗 31
# earn_rate >3 : 600502.SH 安徽建工 18
# earn_rate >3 : 600505.SH 西昌电力 15
# earn_rate >3 : 600506.SH 香梨股份 15
# earn_rate >3 : 600509.SH 天富能源 17
# earn_rate >3 : 600510.SH 黑牡丹 15
# earn_rate >3 : 600513.SH 联环药业 12
# earn_rate >3 : 600517.SH 置信电气 19
# earn_rate >3 : 600519.SH 贵州茅台 12
# earn_rate >3 : 600521.SH 华海药业 17
# earn_rate >3 : 600522.SH 中天科技 21
# earn_rate >3 : 600523.SH 贵航股份 32
# earn_rate >3 : 600527.SH 江南高纤 26
# earn_rate >3 : 600528.SH 中铁工业 26
# earn_rate >3 : 600538.SH 国发股份 15
# earn_rate >3 : 600540.SH 新赛股份 19
# earn_rate >3 : 600546.SH 山煤国际 21
# earn_rate >3 : 600547.SH 山东黄金 27
# earn_rate >3 : 600552.SH 凯盛科技 13
# earn_rate >3 : 600556.SH 天下秀 16
# earn_rate >3 : 600558.SH 大西洋 26
# earn_rate >3 : 600560.SH 金自天正 18
# earn_rate >3 : 600562.SH 国睿科技 23
# earn_rate >3 : 600565.SH 迪马股份 19
# earn_rate >3 : 600570.SH 恒生电子 19
# earn_rate >3 : 600577.SH 精达股份 20
# earn_rate >3 : 600584.SH 长电科技 20
# earn_rate >3 : 600586.SH 金晶科技 20
# earn_rate >3 : 600596.SH 新安股份 18
# earn_rate >3 : 600602.SH 云赛智联 12
# earn_rate >3 : 600606.SH 绿地控股 26
# earn_rate >3 : 600608.SH ST沪科 14
# earn_rate >3 : 600617.SH 国新能源 15
# earn_rate >3 : 600621.SH 华鑫股份 20
# earn_rate >3 : 600629.SH 华建集团 29
# earn_rate >3 : 600635.SH 大众公用 28
# earn_rate >3 : 600650.SH 锦江投资 22
# earn_rate >3 : 600651.SH 飞乐音响 27
# earn_rate >3 : 600661.SH 昂立教育 14
# earn_rate >3 : 600662.SH 强生控股 26
# earn_rate >3 : 600663.SH 陆家嘴 22
# earn_rate >3 : 600667.SH 太极实业 21
# earn_rate >3 : 600671.SH 天目药业 17
# earn_rate >3 : 600675.SH 中华企业 25
# earn_rate >3 : 600678.SH 四川金顶 20
# earn_rate >3 : 600684.SH 珠江实业 19
# earn_rate >3 : 600685.SH 中船防务 26
# earn_rate >3 : 600691.SH 阳煤化工 17
# earn_rate >3 : 600694.SH 大商股份 15
# earn_rate >3 : 600696.SH ST岩石 12
# earn_rate >3 : 600704.SH 物产中大 26
# earn_rate >3 : 600707.SH 彩虹股份 19
# earn_rate >3 : 600711.SH 盛屯矿业 16
# earn_rate >3 : 600714.SH 金瑞矿业 25
# earn_rate >3 : 600716.SH 凤凰股份 11
# earn_rate >3 : 600720.SH 祁连山 17
# earn_rate >3 : 600722.SH 金牛化工 18
# earn_rate >3 : 600728.SH 佳都科技 13
# earn_rate >3 : 600735.SH 新华锦 16
# earn_rate >3 : 600737.SH 中粮糖业 28
# earn_rate >3 : 600740.SH 山西焦化 20
# earn_rate >3 : 600744.SH 华银电力 24
# earn_rate >3 : 600749.SH 西藏旅游 20
# earn_rate >3 : 600753.SH 东方银星 13
# earn_rate >3 : 600756.SH 浪潮软件 18
# earn_rate >3 : 600757.SH 长江传媒 11
# earn_rate >3 : 600758.SH 红阳能源 30
# earn_rate >3 : 600764.SH 中国海防 17
# earn_rate >3 : 600769.SH 祥龙电业 20
# earn_rate >3 : 600774.SH 汉商集团 7
# earn_rate >3 : 600777.SH 新潮能源 12
# earn_rate >3 : 600778.SH 友好集团 20
# earn_rate >3 : 600779.SH 水井坊 21
# earn_rate >3 : 600781.SH ST辅仁 10
# earn_rate >3 : 600783.SH 鲁信创投 29
# earn_rate >3 : 600784.SH 鲁银投资 19
# earn_rate >3 : 600785.SH 新华百货 14
# earn_rate >3 : 600789.SH 鲁抗医药 22
# earn_rate >3 : 600792.SH 云煤能源 21
# earn_rate >3 : 600793.SH 宜宾纸业 9
# earn_rate >3 : 600796.SH 钱江生化 13
# earn_rate >3 : 600797.SH 浙大网新 14
# earn_rate >3 : 600801.SH 华新水泥 12
# earn_rate >3 : 600803.SH 新奥股份 10
# earn_rate >3 : 600804.SH 鹏博士 18
# earn_rate >3 : 600805.SH 悦达投资 24
# earn_rate >3 : 600807.SH ST天业 19
# earn_rate >3 : 600812.SH 华北制药 15
# earn_rate >3 : 600814.SH 杭州解百 13
# earn_rate >3 : 600817.SH ST宏盛 4
# earn_rate >3 : 600829.SH 人民同泰 14
# earn_rate >3 : 600833.SH 第一医药 15
# earn_rate >3 : 600834.SH 申通地铁 19
# earn_rate >3 : 600844.SH 丹化科技 28
# earn_rate >3 : 600853.SH 龙建股份 16
# earn_rate >3 : 600864.SH 哈投股份 22
# earn_rate >3 : 600866.SH 星湖科技 14
# earn_rate >3 : 600869.SH 智慧能源 19
# earn_rate >3 : 600875.SH 东方电气 17
# earn_rate >3 : 600877.SH ST电能 14
# earn_rate >3 : 600881.SH 亚泰集团 23
# earn_rate >3 : 600883.SH 博闻科技 21
# earn_rate >3 : 600884.SH 杉杉股份 13
# earn_rate >3 : 600885.SH 宏发股份 11
# earn_rate >3 : 600889.SH 南京化纤 21
# earn_rate >3 : 600890.SH 中房股份 5
# earn_rate >3 : 600893.SH 航发动力 17
# earn_rate >3 : 600958.SH 东方证券 16
# earn_rate >3 : 600962.SH 国投中鲁 25
# earn_rate >3 : 600965.SH 福成股份 11
# earn_rate >3 : 600966.SH 博汇纸业 26
# earn_rate >3 : 600978.SH 宜华生活 24
# earn_rate >3 : 600983.SH 惠而浦 31
# earn_rate >3 : 600986.SH 科达股份 17
# earn_rate >3 : 600987.SH 航民股份 13
# earn_rate >3 : 601000.SH 唐山港 15
# earn_rate >3 : 601007.SH 金陵饭店 20
# earn_rate >3 : 601008.SH 连云港 25
# earn_rate >3 : 601011.SH 宝泰隆 26
# earn_rate >3 : 601012.SH 隆基股份 7
# earn_rate >3 : 601107.SH 四川成渝 22
# earn_rate >3 : 601113.SH ST华鼎 22
# earn_rate >3 : 601117.SH 中国化学 20
# earn_rate >3 : 601118.SH 海南橡胶 30
# earn_rate >3 : 601127.SH 小康股份 6
# earn_rate >3 : 601128.SH 常熟银行 14
# earn_rate >3 : 601155.SH 新城控股 4
# earn_rate >3 : 601188.SH 龙江交通 16
# earn_rate >3 : 601198.SH 东兴证券 17
# earn_rate >3 : 601216.SH 君正集团 15
# earn_rate >3 : 601258.SH ST庞大 28
# earn_rate >3 : 601515.SH 东风股份 13
# earn_rate >3 : 601558.SH ST锐电 33
# earn_rate >3 : 601600.SH 中国铝业 29
# earn_rate >3 : 601608.SH 中信重工 22
# 601609.SH 金田铜业 local variable 'daily_df' referenced before assignment
# 601609.SH 金田铜业 index 22 is out of bounds for axis 0 with size 22
# earn_rate >3 : 601666.SH 平煤股份 36
# earn_rate >3 : 601699.SH 潞安环能 29
# earn_rate >3 : 601717.SH 郑煤机 26
# earn_rate >3 : 601777.SH 力帆股份 22
# earn_rate >3 : 601811.SH 新华文轩 14
# earn_rate >3 : 601858.SH 中国科传 14
# earn_rate >3 : 601869.SH 长飞光纤 4
# earn_rate >3 : 601989.SH 中国重工 23
# earn_rate >3 : 603010.SH 万盛股份 7
# earn_rate >3 : 603012.SH 创力集团 14
# earn_rate >3 : 603017.SH 中衡设计 15
# earn_rate >3 : 603020.SH 爱普股份 15
# earn_rate >3 : 603025.SH 大豪科技 9
# earn_rate >3 : 603033.SH 三维股份 8
# earn_rate >3 : 603036.SH 如通股份 9
# earn_rate >3 : 603038.SH 华立股份 13
# earn_rate >3 : 603039.SH 泛微网络 4
# earn_rate >3 : 603058.SH 永吉股份 11
# earn_rate >3 : 603063.SH 禾望电气 11
# 603095.SH 越剑智能 local variable 'daily_df' referenced before assignment
# earn_rate >3 : 603128.SH 华贸物流 17
# earn_rate >3 : 603138.SH 海量数据 3
# earn_rate >3 : 603161.SH 科华控股 8
# earn_rate >3 : 603166.SH 福达股份 15
# earn_rate >3 : 603186.SH 华正新材 4
# earn_rate >3 : 603188.SH ST亚邦 9
# earn_rate >3 : 603196.SH 日播时尚 1
# 603212.SH 赛伍技术 local variable 'daily_df' referenced before assignment
# 603212.SH 赛伍技术 index 6 is out of bounds for axis 0 with size 4
# 603221.SH 爱丽家居 local variable 'daily_df' referenced before assignment
# earn_rate >3 : 603258.SH 电魂网络 10
# earn_rate >3 : 603259.SH 药明康德 1
# earn_rate >3 : 603268.SH 松发股份 2
# earn_rate >3 : 603269.SH 海鸥股份 7
# earn_rate >3 : 603283.SH 赛腾股份 1
# earn_rate >3 : 603299.SH 苏盐井神 11
# earn_rate >3 : 603309.SH 维力医疗 24
# earn_rate >3 : 603333.SH 尚纬股份 12
# earn_rate >3 : 603336.SH 宏辉果蔬 6
# earn_rate >3 : 603348.SH 文灿股份 2
# 603353.SH 和顺石油 local variable 'daily_df' referenced before assignment
# 603353.SH 和顺石油 index 5 is out of bounds for axis 0 with size 5
# earn_rate >3 : 603355.SH 莱克电气 12
# earn_rate >3 : 603378.SH 亚士创能 6
# 603392.SH N万泰 local variable 'daily_df' referenced before assignment
# earn_rate >3 : 603421.SH 鼎信通讯 7
# 603439.SH 贵州三力 local variable 'daily_df' referenced before assignment
# 603439.SH 贵州三力 index 6 is out of bounds for axis 0 with size 4
# earn_rate >3 : 603518.SH 锦泓集团 20
# earn_rate >3 : 603556.SH 海兴电力 7
# earn_rate >3 : 603579.SH 荣泰健康 7
# earn_rate >3 : 603585.SH 苏利股份 7
# earn_rate >3 : 603590.SH 康辰药业 1
# earn_rate >3 : 603595.SH 东尼电子 7
# earn_rate >3 : 603599.SH 广信股份 8
# earn_rate >3 : 603615.SH 茶花股份 6
# earn_rate >3 : 603619.SH 中曼石油 7
# earn_rate >3 : 603636.SH 南威软件 4
# earn_rate >3 : 603657.SH 春光科技 7
# 603682.SH 锦和商业 local variable 'daily_df' referenced before assignment
# 603682.SH 锦和商业 index 5 is out of bounds for axis 0 with size 2
# earn_rate >3 : 603693.SH 江苏新能 9
# earn_rate >3 : 603696.SH 安记食品 5
# earn_rate >3 : 603717.SH 天域生态 9
# earn_rate >3 : 603777.SH 来伊份 12
# earn_rate >3 : 603788.SH 宁波高发 6
# earn_rate >3 : 603799.SH 华友钴业 9
# earn_rate >3 : 603800.SH 道森股份 15
# earn_rate >3 : 603801.SH 志邦家居 5
# earn_rate >3 : 603816.SH 顾家家居 9
# earn_rate >3 : 603817.SH 海峡环保 12
# earn_rate >3 : 603822.SH 嘉澳环保 3
# earn_rate >3 : 603838.SH 四通股份 6
# earn_rate >3 : 603881.SH 数据港 5
# earn_rate >3 : 603886.SH 元祖股份 7
# earn_rate >3 : 603889.SH 新澳股份 14
# earn_rate >3 : 603890.SH 春秋电子 3
# earn_rate >3 : 603929.SH 亚翔集成 10
# earn_rate >3 : 603969.SH 银龙股份 11
# earn_rate >3 : 603977.SH 国泰集团 6
# earn_rate >3 : 603979.SH 金诚信 9
# earn_rate >3 : 603987.SH 康德莱 9
# earn_rate >3 : 603991.SH 至正股份 6
# earn_rate >3 : 603997.SH 继峰股份 4
# (16, 81)
#     pre_index    ts_code trade_date   open   high    low  close  pre_close  \
# 0          58  603999.SH   20160309  32.40  35.17  32.00  33.85      33.48
# 5         264  603999.SH   20170109  30.55  31.95  30.53  31.46      30.41
# 6         273  603999.SH   20170120  27.25  27.83  27.13  27.75      27.35
# 8         345  603999.SH   20170517  21.79  22.18  21.65  22.04      21.81
# 9         356  603999.SH   20170605  19.00  19.44  19.00  19.35      19.00
# 12        466  603999.SH   20171113   8.94   9.12   8.92   9.03       8.92
# 14        498  603999.SH   20171227   7.41   8.18   7.39   7.72       7.44
# 16        629  603999.SH   20180713   5.78   5.78   5.67   5.72       5.71
# 17        632  603999.SH   20180718   5.72   5.84   5.70   5.73       5.72
# 18        646  603999.SH   20180807   5.56   5.75   5.51   5.69       5.51
# 20        679  603999.SH   20180921   5.19   5.28   5.18   5.26       5.17
# 21        694  603999.SH   20181022   4.18   4.41   4.15   4.35       4.16
# 23        753  603999.SH   20190115   4.94   5.05   4.94   5.04       4.94
# 24        755  603999.SH   20190117   5.00   5.21   4.95   5.07       4.98
# 26        848  603999.SH   20190611   5.28   5.53   5.28   5.50       5.33
# 28       1041  603999.SH   20200325   6.02   6.06   5.94   6.00       5.92
#
#     change  pct_chg  ...  postday_close  buy_price  target_price  \
# 0     0.37   1.1100  ...          32.85      33.85       34.8655
# 5     1.05   3.4500  ...          30.93      31.46       32.4038
# 6     0.40   1.4600  ...          28.11      27.75       28.5825
# 8     0.23   1.0500  ...          22.04      22.04       22.7012
# 9     0.35   1.8400  ...          19.38      19.35       19.9305
# 12    0.11   1.2300  ...           8.93       9.03        9.3009
# 14    0.28   3.7600  ...           7.72       7.72        7.9516
# 16    0.01   0.1800  ...           5.65       5.72        5.8916
# 17    0.01   0.1700  ...           5.83       5.73        5.9019
# 18    0.18   3.2668  ...           5.76       5.69        5.8607
# 20    0.09   1.7408  ...           5.23       5.26        5.4178
# 21    0.19   4.5673  ...           4.32       4.35        4.4805
# 23    0.10   2.0243  ...           4.98       5.04        5.1912
# 24    0.09   1.8072  ...           5.18       5.07        5.2221
# 26    0.17   3.1895  ...           5.51       5.50        5.6650
# 28    0.08   1.3514  ...           6.00       6.00        6.1800
#
#     minimal_price  sell_price  hold_period               sell_reason  \
# 0         32.8345     32.8500          1.0  get minimal_price profit
# 5         30.5162     29.9700          2.0  get minimal_price profit
# 6         26.9175     28.5825          1.0         get target profit
# 8         21.3788     20.8800          3.0  get minimal_price profit
# 9         18.7695     19.9305          2.0         get target profit
# 12         8.7591      8.7400          2.0  get minimal_price profit
# 14         7.4884      7.8100          4.0            get max period
# 16         5.5484      5.6500          1.0           get sell signal
# 17         5.5581      5.9019          1.0         get target profit
# 18         5.5193      5.7600          1.0  get minimal_price profit
# 20         5.1022      5.0800          3.0  get minimal_price profit
# 21         4.2195      4.4805          2.0         get target profit
# 23         4.8888      4.9800          1.0           get sell signal
# 24         4.9179      5.2221          1.0         get target profit
# 26         5.3350      5.6650          2.0         get target profit
# 28         5.8200      5.7300          3.0  get minimal_price profit
#
#     earn_rate  earn_rate_per_day    win
# 0   -2.954210          -2.954210  False
# 5   -4.736173          -2.368086  False
# 6    3.000000           3.000000   True
# 8   -5.263158          -1.754386  False
# 9    3.000000           1.500000   True
# 12  -3.211517          -1.605759  False
# 14   1.165803           0.291451   True
# 16  -1.223776          -1.223776  False
# 17   3.000000           3.000000   True
# 18   1.230228           1.230228   True
# 20  -3.422053          -1.140684  False
# 21   3.000000           1.500000   True
# 23  -1.190476          -1.190476  False
# 24   3.000000           3.000000   True
# 26   3.000000           1.500000   True
# 28  -4.500000          -1.500000  False
#
# [16 rows x 81 columns]

# %%
# concat all df 
save_dir = "./output/select_by_3_percent/reesult_policy1/"

all_df = pd.DataFrame()
for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    try:
        select_df = pd.read_csv(save_dir+stock_code+".csv")
    except Exception as err:
        print(stock_code,stock_name,err)
    if len(select_df) > 1:
        if i == 0:
            all_df = select_df
        else:
            all_df = pd.concat([all_df,select_df])
all_df.to_csv("./output/select_by_3_percent/result_policy1.csv",index = False)

# %%
all_df = all_df.loc[all_df.earn_rate.values>-15,:]
all_df.sort_values(by = "trade_date",ascending = "True", inplace = True )
print(all_df.shape)
all_df.head(20)
# Out:
# (38816, 81)
#    pre_index    ts_code  trade_date   open   high    low  close  pre_close  \
# 0         36  000783.SZ    20100303  17.43  17.83  17.23  17.76      17.49
# 0         36  601918.SH    20100303  15.20  15.44  15.01  15.43      15.19
# 0         37  601898.SH    20100303  11.80  11.91  11.62  11.89      11.77
# 0         37  601001.SH    20100303  35.27  35.88  34.62  35.81      35.17
# 0         38  601666.SH    20100304  26.02  26.65  25.79  25.86      25.94
# 0         39  600999.SH    20100305  28.40  29.36  28.35  28.93      28.25
# 0         39  600109.SH    20100305  20.11  20.78  20.11  20.47      20.05
# 0         39  000728.SZ    20100305  18.00  18.54  18.00  18.12      17.89
# 0         39  600704.SH    20100305  21.00  21.88  20.81  21.39      20.71
# 0         39  601939.SH    20100305   5.60   5.64   5.58   5.62       5.59
# 0         40  601088.SH    20100308  28.71  29.04  28.61  28.89      28.51
# 0         40  601398.SH    20100308   4.86   4.87   4.83   4.86       4.84
# 0         40  601328.SH    20100308   8.14   8.23   8.11   8.20       8.12
# 0         40  601318.SH    20100308  45.60  46.34  45.42  46.16      45.49
# 0         39  601699.SH    20100308  40.17  40.58  39.82  40.11      39.64
# 0         41  600028.SH    20100309  11.11  11.25  10.99  11.17      11.11
# 0         40  600348.SH    20100309  36.66  38.10  36.00  37.34      36.68
# 0         40  000933.SZ    20100309  27.85  29.12  26.99  28.76      27.85
# 0         41  600030.SH    20100309  27.07  27.37  26.66  27.19      27.08
# 0         41  000568.SZ    20100310  32.10  33.11  32.10  32.78      31.94
#
#    change  pct_chg  ...  postday_close  buy_price  target_price  \
# 0    0.27     1.54  ...          17.22      17.76       18.2928
# 0    0.24     1.58  ...          14.98      15.43       15.8929
# 0    0.12     1.02  ...          11.58      11.89       12.2467
# 0    0.64     1.82  ...          35.17      35.81       36.8843
# 0   -0.08    -0.31  ...          25.68      25.86       26.6358
# 0    0.68     2.41  ...          28.98      28.93       29.7979
# 0    0.42     2.09  ...          20.50      20.47       21.0841
# 0    0.23     1.29  ...          18.26      18.12       18.6636
# 0    0.68     3.28  ...          21.32      21.39       22.0317
# 0    0.03     0.54  ...           5.61       5.62        5.7886
# 0    0.38     1.33  ...          29.18      28.89       29.7567
# 0    0.02     0.41  ...           4.91       4.86        5.0058
# 0    0.08     0.99  ...           8.24       8.20        8.4460
# 0    0.67     1.47  ...          47.05      46.16       47.5448
# 0    0.47     1.19  ...          41.02      40.11       41.3133
# 0    0.06     0.54  ...          11.26      11.17       11.5051
# 0    0.66     1.80  ...          36.78      37.34       38.4602
# 0    0.91     3.27  ...          28.30      28.76       29.6228
# 0    0.11     0.41  ...          27.24      27.19       28.0057
# 0    0.84     2.63  ...          32.80      32.78       33.7634
#
#    minimal_price  sell_price  hold_period               sell_reason  \
# 0        17.2272     17.2200          1.0  get minimal_price profit
# 0        14.9671     14.9800          1.0  get minimal_price profit
# 0        11.5333     11.5800          1.0           get sell signal
# 0        34.7357     34.9500          2.0           get sell signal
# 0        25.0842     26.6358          3.0         get target profit
# 0        28.0621     28.9800          1.0           get sell signal
# 0        19.8559     20.5900          2.0           get sell signal
# 0        17.5764     18.6636          3.0         get target profit
# 0        20.7483     21.3200          1.0           get sell signal
# 0         5.4514      5.6300          3.0           get sell signal
# 0        28.0233     28.7700          4.0            get max period
# 0         4.7142      4.9100          1.0           get sell signal
# 0         7.9540      8.2000          2.0           get sell signal
# 0        44.7752     47.5448          1.0         get target profit
# 0        38.9067     41.3133          1.0         get target profit
# 0        10.8349     11.5051          2.0         get target profit
# 0        36.2198     35.8900          3.0  get minimal_price profit
# 0        27.8972     27.3200          4.0  get minimal_price profit
# 0        26.3743     28.0057          3.0         get target profit
# 0        31.7966     31.8000          2.0  get minimal_price profit
#
#    earn_rate  earn_rate_per_day    win
# 0  -3.040541          -3.040541  False
# 0  -2.916397          -2.916397  False
# 0  -2.607233          -2.607233  False
# 0  -2.401564          -1.200782  False
# 0   3.000000           1.000000   True
# 0   0.172831           0.172831   True
# 0   0.586224           0.293112   True
# 0   3.000000           1.000000   True
# 0  -0.327256          -0.327256  False
# 0   0.177936           0.059312   True
# 0  -0.415369          -0.103842  False
# 0   1.028807           1.028807   True
# 0   0.000000           0.000000  False
# 0   3.000000           3.000000   True
# 0   3.000000           3.000000   True
# 0   3.000000           1.500000   True
# 0  -3.883235          -1.294412  False
# 0  -5.006954          -1.251739  False
# 0   3.000000           1.000000   True
# 0  -2.989628          -1.494814  False
#
# [20 rows x 81 columns]

# %%
all_df.columns.values
# Out:
# array(['pre_index', 'ts_code', 'trade_date', 'open', 'high', 'low',
#        'close', 'pre_close', 'change', 'pct_chg', 'vol', 'amount',
#        'trade_date_stamp', 'K', 'D', 'J', 'kdj_signal', 'sema', 'lema',
#        'dif', 'dea', 'macd', 'macd_signal', 'close_weekly', 'open_weekly',
#        'high_weekly', 'low_weekly', 'pre_close_weekly', 'change_weekly',
#        'pct_chg_weekly', 'vol_weekly', 'amount_weekly', 'K_weekly',
#        'D_weekly', 'J_weekly', 'kdj_signal_weekly', 'sema_weekly',
#        'lema_weekly', 'dif_weekly', 'dea_weekly', 'macd_weekly',
#        'macd_signal_weekly', 'close_monthly', 'open_monthly',
#        'high_monthly', 'low_monthly', 'pre_close_monthly',
#        'change_monthly', 'pct_chg_monthly', 'vol_monthly',
#        'amount_monthly', 'K_monthly', 'D_monthly', 'J_monthly',
#        'kdj_signal_monthly', 'sema_monthly', 'lema_monthly',
#        'dif_monthly', 'dea_monthly', 'macd_monthly',
#        'macd_signal_monthly', 'var', 'xx', 'xx1', 'yy', 'cross_signal',
#        'buy_signal', 'sell_signal', 'postday_open', 'postday_high',
#        'postday_low', 'postday_close', 'buy_price', 'target_price',
#        'minimal_price', 'sell_price', 'hold_period', 'sell_reason',
#        'earn_rate', 'earn_rate_per_day', 'win'], dtype=object)

# %%
all_df["postday_high_pst"] = (all_df["postday_high"] /all_df["close"] -1)*100
all_df["postday_open_pst"] = (all_df["postday_open"] /all_df["close"] -1)*100

# %%
def myScatter(map_df, col1 = "x", col2 = "y", color = None, save_dir = "./temp/"):
    # plot it
    cm=plt.cm.inferno  # ['viridis', 'plasma', 'inferno', 'magma', 'cividis']
    x = map_df[col1].values
    y = map_df[col2].values
    if not color:
        color = col1
    c = map_df[color].values
        
    plt.figure(figsize = (11,8))
    vmin = np.min(c)
    vmax = np.max(c)
    sc = plt.scatter(x, y, c=c, vmin=vmin, vmax=vmax, s=5, cmap=cm)
    plt.colorbar(sc)
    plt.xlabel(col1)
    plt.ylabel(col2)
    plt.savefig(save_dir+"scatter_"+col1+"_"+col2+"_"+color+".png")
    return 0

# %%
myScatter(all_df, col1 = "postday_high_pst", col2 = "pct_chg", color = "earn_rate", save_dir = "./temp/")
# Out:
# 0

# %%
x = all_df.earn_rate.values
y = all_df.close.values
plt.scatter(x, y,s=35)
plt.ylim(1,20)
# Out:
# (1.0, 20.0)

# %%
data_df = all_df.groupby('trade_date').agg({"earn_rate":np.mean,"earn_rate_per_day":np.mean})
data_df["earn_rate_add1"] = (data_df["earn_rate"]+100)/100
print(data_df.shape)
data_df.head()
# Out:
# (1847, 3)
#             earn_rate  earn_rate_per_day  earn_rate_add1
# trade_date
# 20100303    -2.741433          -2.441238        0.972586
# 20100304     3.000000           1.000000        1.030000
# 20100305     0.721947           0.239600        1.007219
# 20100308     1.322688           1.384993        1.013227
# 20100309    -0.722547          -0.011538        0.992775

# %%
from functools import reduce  
# data_df["earn_rate_acc"]
a = [reduce(lambda x, y: x+y, data_df.earn_rate.values[:i+1]) for i in range(len(data_df))] # len(data_df)
b = [reduce(lambda x, y: x*y, data_df.earn_rate_add1.values[:i+1]) for i in range(len(data_df))] # len(data_df)

# %%
plt.plot(a)

# %%
plt.figure(figsize=(16,5))
plt.plot(b)

# %%
from mylab.stock.myread import getIndexDaily
index_df = getIndexDaily("399001.SZ", "20100303")
index_df["pct_chg_add1"] = (index_df["pct_chg"]+100)/100
b = [reduce(lambda x, y: x*y, index_df.pct_chg_add1.values[:i+1]) for i in range(len(index_df))] # len(data_df)
plt.figure(figsize=(16,5))
plt.plot(b)

# %%
index_df = getIndexBasic()
index_df.head()
# Out:
#      ts_code   name market publisher category  base_date  base_point  \
# 0  398001.SZ  湾创100   SZSE       深交所     主题指数   20170630      1000.0
# 1  398002.SZ   南山50   SZSE       深交所     主题指数   20121231      1000.0
# 2  398003.SZ   国证芯片   SZSE       深交所   二级行业指数   20021231      1000.0
# 3  399001.SZ   深证成指   SZSE       深交所     规模指数   19940720      1000.0
# 4  399002.SZ   深成指R   SZSE       深交所     规模指数   19940720      1000.0
#
#    list_date
# 0   20190409
# 1   20191231
# 2   20150217
# 3   19950123
# 4   19950123
