# %%
import time
import datetime
import os
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import tushare as ts
ts.set_token('29eaf3bcac23df4c6d025de157ab2d53beead3391fbe6e83b4ebcb6c')
pro = ts.pro_api()

import mpl_finance as mpf
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib.pylab import date2num
import matplotlib.gridspec as gridspec
import matplotlib as mpl
import seaborn as sns
sns.set()
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = 'SimHei'
# Out:
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\mpl_finance.py:22: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   category=DeprecationWarning)

# %%
from mylab.stock.myread import *
from mylab.stock.myfeature import *
from mylab.stock.myplot import *
from mylab.stock.my3point import *

# %%
SAVE_CSV = True
LOCAL = not True

GET_DAILY = True
SELECT_STOCK = True

start_date = "20160101"
end_date = "20200413"

# %% [markdown]
# # get all Stocks Info

# %%
#获取基础信息数据，包括股票代码、名称、上市日期、退市日期等
pool_df = getStockBasic(LOCAL = False,noSTKC = True, list_data = "20180101")
# pool_df = pd.read_csv("./data/stock/blue_stock_rank_3.csv" )

print('获得上市股票总数：', len(pool_df)-1)
pool_df.head()
# Out:
# 获得上市股票总数： 2640
#      ts_code  symbol  name area industry market exchange list_status  \
# 0  000001.SZ  000001  平安银行   深圳       银行     主板     SZSE           L
# 1  000002.SZ  000002   万科A   深圳     全国地产     主板     SZSE           L
# 2  000004.SZ  000004  国农科技   深圳     生物制药     主板     SZSE           L
# 3  000005.SZ  000005  世纪星源   深圳     环境保护     主板     SZSE           L
# 4  000006.SZ  000006  深振业A   深圳     区域地产     主板     SZSE           L
#
#   list_date delist_date
# 0  19910403        None
# 1  19910129        None
# 2  19910114        None
# 3  19901210        None
# 4  19920427        None

# %% [markdown]
# # plot demo

# %%
start_date = "20190901"
# end_date = "20200101"
stock_code = "000001.SZ"
save_dir = "./output/select_by_3_percent/"

stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
stock_df = get3Percent(stock_df)
plotStock3Pct(stock_df ,SAVE = False, save_dir =save_dir)
# Out:
# 0

# %%
stock_df.loc[stock_df["trade_date"] == "20200410", "dates"].values[0]
# Out:
# 145

# %%
stock_df.head()
# Out:
#   trade_date    ts_code   open   high    low  close  pre_close  change  \
# 0   20190902  000001.SZ  14.15  14.50  14.11  14.45      14.16    0.29
# 1   20190903  000001.SZ  14.48  14.51  14.25  14.30      14.45   -0.15
# 2   20190904  000001.SZ  14.32  14.50  14.31  14.44      14.30    0.14
# 3   20190905  000001.SZ  14.56  14.85  14.55  14.58      14.44    0.14
# 4   20190906  000001.SZ  14.71  14.81  14.62  14.81      14.58    0.23
#
#    pct_chg         vol  ...  trade_date2  dates   lag_5  lag_10  lag_20  \
# 0   2.0480  1360201.30  ...     737304.0      0     NaN     NaN     NaN
# 1  -1.0381   858653.65  ...     737305.0      1     NaN     NaN     NaN
# 2   0.9790   973964.87  ...     737306.0      2     NaN     NaN     NaN
# 3   0.9695  1768051.43  ...     737307.0      3     NaN     NaN     NaN
# 4   1.5775   986432.80  ...     737308.0      4  14.516     NaN     NaN
#
#    lag_30  lag_60  lag_120  lag_250  up
# 0     NaN     NaN      NaN      NaN   1
# 1     NaN     NaN      NaN      NaN   0
# 2     NaN     NaN      NaN      NaN   1
# 3     NaN     NaN      NaN      NaN   1
# 4     NaN     NaN      NaN      NaN   1
#
# [5 rows x 79 columns]

# %% [markdown]
# # conduct the policy

# %%
from mylab.stock.mypolicy import actionDay
from mylab.stock.mypolicy import action3Per

# %%
# policy
start_date = "20100101"
end_date = "20200430"
# stock_code = "002499.SZ"
save_dir = "./output/select_by_3_percent/reesult_policy1/"

for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    try:
        stock_df = getStock(stock_code,start_date, end_date, LOCAL = True)
        stock_df = get3Percent(stock_df)
        # select df 
        select_df = stock_df.loc[stock_df.buy_signal.values>0,:]
        # reindex select df otherwise wrong !!!
        select_df = select_df.iloc[1:-1,:]
        select_df = select_df.reset_index()
        select_df.rename(columns = {"index":"pre_index"}, inplace = True)
#         print(stock_code,stock_name,len(select_df))
    except Exception as err:
        print(stock_code,stock_name,err)
        
    try:
        # initiate columns
        select_df["postday_open"] = np.nan 
        select_df["postday_high"] = np.nan 
        select_df["postday_low"] = np.nan 
        select_df["postday_close"] = np.nan 
        select_df["postday_vol"] = np.nan 
        select_df["preday_open"] = np.nan 
        select_df["preday_high"] = np.nan 
        select_df["preday_low"] = np.nan 
        select_df["preday_close"] = np.nan 
        select_df["preday_vol"] = np.nan 
        select_df["buy_price"] = np.nan
        select_df["target_price"] = np.nan
        select_df["minimal_price"] = np.nan
        select_df["sell_price"] = np.nan
        select_df["hold_period"] = np.nan
        select_df["sell_reason"] = np.nan 
        for i in select_df.index.values:
            # policy
            stock_ix = select_df.pre_index.values[i] 
            # 15 天以内出现过两次底部突破 才符合条件
            if sum(stock_df.buy_signal.values[stock_ix-15:stock_ix-1]) == 0:
                continue
            # 当天涨停的股票不算
            if select_df.pct_chg.values[i] > 9.7:
                continue
            # save necessary information
            select_df.buy_price.values[i] = stock_df.close.values[stock_ix]
            select_df.target_price.values[i] = stock_df.close.values[stock_ix] *1.03 
            select_df.minimal_price.values[i] = stock_df.close.values[stock_ix] *0.97 
            select_df["postday_open"][i] = stock_df.open.values[stock_ix+1]
            select_df["postday_high"][i] = stock_df.high.values[stock_ix+1]
            select_df["postday_low"][i] = stock_df.low.values[stock_ix+1]
            select_df["postday_close"][i] = stock_df.close.values[stock_ix+1]
            select_df["postday_vol"][i] = stock_df.vol.values[stock_ix+1]
            select_df["preday_open"][i] = stock_df.open.values[stock_ix-1]
            select_df["preday_high"][i] = stock_df.high.values[stock_ix-1]
            select_df["preday_low"][i] = stock_df.low.values[stock_ix-1]
            select_df["preday_close"][i] = stock_df.close.values[stock_ix-1]
            select_df["preday_vol"][i] = stock_df.vol.values[stock_ix-1]
            # conduct policy
            select_df = action3Per(stock_df,select_df,i)
            
        # calculate some important inform after all buy-sell points are conducted
        select_df["earn_rate"] = (select_df["sell_price"]/select_df["buy_price"]-1)*100
        select_df["earn_rate_per_day"] = select_df["earn_rate"]/select_df["hold_period"]
        select_df["win"] = select_df["earn_rate"] > 0
        # drop nan and save
        select_df = select_df.dropna()
        if sum(select_df["earn_rate"]>3.1)>0:
            print("earn_rate >3 :",stock_code,stock_name,len(select_df))
        select_df.to_csv(save_dir+stock_code+".csv", index = False)
#         print(stock_code,stock_name,len(select_df))
    except Exception as err:
        print(stock_code,stock_name,err)
print(select_df.shape)
select_df.head(20)
# Out:
# earn_rate >3 : 000005.SZ 世纪星源 24
# earn_rate >3 : 000014.SZ 沙河股份 22
# earn_rate >3 : 000019.SZ 深粮控股 20
# earn_rate >3 : 000021.SZ 深科技 20
# earn_rate >3 : 000023.SZ 深天地A 17
# earn_rate >3 : 000025.SZ 特力A 25
# earn_rate >3 : 000030.SZ 富奥股份 9
# earn_rate >3 : 000032.SZ 深桑达A 20
# earn_rate >3 : 000037.SZ 深南电A 25
# earn_rate >3 : 000040.SZ 东旭蓝天 14
# earn_rate >3 : 000049.SZ 德赛电池 22
# earn_rate >3 : 000055.SZ 方大集团 23
# earn_rate >3 : 000058.SZ 深赛格 15
# earn_rate >3 : 000069.SZ 华侨城A 12
# earn_rate >3 : 000070.SZ 特发信息 13
# earn_rate >3 : 000078.SZ 海王生物 23
# earn_rate >3 : 000096.SZ 广聚能源 19
# earn_rate >3 : 000100.SZ TCL科技 14
# earn_rate >3 : 000157.SZ 中联重科 22
# earn_rate >3 : 000338.SZ 潍柴动力 15
# earn_rate >3 : 000407.SZ 胜利股份 11
# earn_rate >3 : 000413.SZ 东旭光电 16
# earn_rate >3 : 000417.SZ 合肥百货 15
# earn_rate >3 : 000425.SZ 徐工机械 17
# earn_rate >3 : 000488.SZ 晨鸣纸业 24
# earn_rate >3 : 000498.SZ 山东路桥 22
# earn_rate >3 : 000502.SZ 绿景控股 19
# earn_rate >3 : 000507.SZ 珠海港 19
# earn_rate >3 : 000513.SZ 丽珠集团 12
# earn_rate >3 : 000516.SZ 国际医学 19
# earn_rate >3 : 000520.SZ 长航凤凰 21
# earn_rate >3 : 000524.SZ 岭南控股 13
# earn_rate >3 : 000526.SZ 紫光学大 4
# earn_rate >3 : 000537.SZ 广宇发展 28
# earn_rate >3 : 000538.SZ 云南白药 11
# earn_rate >3 : 000540.SZ 中天金融 16
# earn_rate >3 : 000543.SZ 皖能电力 22
# earn_rate >3 : 000545.SZ 金浦钛业 13
# earn_rate >3 : 000555.SZ 神州信息 15
# earn_rate >3 : 000557.SZ 西部创业 9
# earn_rate >3 : 000558.SZ 莱茵体育 20
# earn_rate >3 : 000559.SZ 万向钱潮 27
# earn_rate >3 : 000563.SZ 陕国投A 14
# earn_rate >3 : 000567.SZ 海德股份 23
# earn_rate >3 : 000570.SZ 苏常柴A 16
# earn_rate >3 : 000581.SZ 威孚高科 9
# earn_rate >3 : 000593.SZ 大通燃气 11
# earn_rate >3 : 000603.SZ 盛达资源 26
# earn_rate >3 : 000606.SZ 顺利办 16
# earn_rate >3 : 000610.SZ 西安旅游 13
# earn_rate >3 : 000616.SZ 海航投资 26
# earn_rate >3 : 002823.SZ 凯中精密 12
# earn_rate >3 : 002824.SZ 和胜股份 7
# earn_rate >3 : 002830.SZ 名雕股份 10
# earn_rate >3 : 002836.SZ 新宏泽 6
# earn_rate >3 : 002848.SZ 高斯贝尔 8
# earn_rate >3 : 002852.SZ 道道全 13
# earn_rate >3 : 002873.SZ 新天药业 6
# earn_rate >3 : 002887.SZ 绿茵生态 7
# earn_rate >3 : 002890.SZ 弘宇股份 6
# earn_rate >3 : 002891.SZ 中宠股份 5
# earn_rate >3 : 002903.SZ 宇环数控 6
# earn_rate >3 : 002915.SZ 中欣氟材 5
# earn_rate >3 : 002917.SZ 金奥博 3
# earn_rate >3 : 002920.SZ 德赛西威 7
# earn_rate >3 : 002928.SZ 华夏航空 11
# earn_rate >3 : 002932.SZ 明德生物 6
# earn_rate >3 : 600006.SH 东风汽车 25
# earn_rate >3 : 600008.SH 首创股份 24
# earn_rate >3 : 600018.SH 上港集团 21
# earn_rate >3 : 600027.SH 华电国际 23
# earn_rate >3 : 600031.SH 三一重工 13
# earn_rate >3 : 600039.SH 四川路桥 14
# earn_rate >3 : 600053.SH 九鼎投资 24
# earn_rate >3 : 600055.SH 万东医疗 14
# earn_rate >3 : 600063.SH 皖维高新 18
# earn_rate >3 : 600066.SH 宇通客车 10
# earn_rate >3 : 600068.SH 葛洲坝 17
# earn_rate >3 : 600070.SH 浙江富润 25
# earn_rate >3 : 600078.SH 澄星股份 32
# earn_rate >3 : 600079.SH 人福医药 10
# earn_rate >3 : 600095.SH 哈高科 26
# earn_rate >3 : 600098.SH 广州发展 23
# earn_rate >3 : 600105.SH 永鼎股份 17
# earn_rate >3 : 600106.SH 重庆路桥 16
# earn_rate >3 : 600107.SH 美尔雅 31
# earn_rate >3 : 600111.SH 北方稀土 17
# earn_rate >3 : 600115.SH 东方航空 26
# earn_rate >3 : 600116.SH 三峡水利 16
# earn_rate >3 : 600117.SH 西宁特钢 25
# earn_rate >3 : 600120.SH 浙江东方 12
# earn_rate >3 : 600125.SH 铁龙物流 15
# earn_rate >3 : 600128.SH 弘业股份 29
# earn_rate >3 : 600133.SH 东湖高新 20
# earn_rate >3 : 600141.SH 兴发集团 23
# earn_rate >3 : 600151.SH 航天机电 19
# earn_rate >3 : 600152.SH 维科技术 16
# earn_rate >3 : 600160.SH 巨化股份 22
# earn_rate >3 : 600162.SH 香江控股 22
# earn_rate >3 : 600177.SH 雅戈尔 23
# earn_rate >3 : 600186.SH 莲花健康 17
# earn_rate >3 : 600189.SH 吉林森工 22
# earn_rate >3 : 600191.SH 华资实业 24
# earn_rate >3 : 600192.SH 长城电工 17
# earn_rate >3 : 600195.SH 中牧股份 5
# earn_rate >3 : 600207.SH 安彩高科 20
# earn_rate >3 : 600211.SH 西藏药业 10
# earn_rate >3 : 600217.SH 中再资环 23
# earn_rate >3 : 600242.SH 中昌数据 14
# earn_rate >3 : 600249.SH 两面针 18
# earn_rate >3 : 600250.SH 南纺股份 13
# earn_rate >3 : 600257.SH 大湖股份 20
# earn_rate >3 : 600259.SH 广晟有色 20
# earn_rate >3 : 600260.SH 凯乐科技 12
# earn_rate >3 : 600266.SH 城建发展 14
# earn_rate >3 : 600268.SH 国电南自 17
# earn_rate >3 : 600276.SH 恒瑞医药 5
# earn_rate >3 : 600278.SH 东方创业 18
# earn_rate >3 : 600287.SH 江苏舜天 16
# earn_rate >3 : 600288.SH 大恒科技 19
# earn_rate >3 : 600291.SH 西水股份 20
# earn_rate >3 : 600295.SH 鄂尔多斯 26
# earn_rate >3 : 600303.SH 曙光股份 30
# earn_rate >3 : 600316.SH 洪都航空 11
# earn_rate >3 : 600317.SH 营口港 18
# earn_rate >3 : 600338.SH 西藏珠峰 15
# earn_rate >3 : 600350.SH 山东高速 19
# earn_rate >3 : 600355.SH 精伦电子 9
# earn_rate >3 : 600358.SH 国旅联合 16
# earn_rate >3 : 600362.SH 江西铜业 36
# earn_rate >3 : 600366.SH 宁波韵升 21
# earn_rate >3 : 600379.SH 宝光股份 10
# earn_rate >3 : 600381.SH 青海春天 15
# earn_rate >3 : 600382.SH 广东明珠 20
# earn_rate >3 : 600387.SH 海越能源 23
# earn_rate >3 : 600396.SH 金山股份 20
# earn_rate >3 : 600398.SH 海澜之家 12
# earn_rate >3 : 600406.SH 国电南瑞 13
# earn_rate >3 : 600415.SH 小商品城 28
# earn_rate >3 : 600418.SH 江淮汽车 22
# earn_rate >3 : 600422.SH 昆药集团 14
# earn_rate >3 : 600428.SH 中远海特 23
# earn_rate >3 : 600433.SH 冠豪高新 17
# earn_rate >3 : 600438.SH 通威股份 14
# earn_rate >3 : 600446.SH 金证股份 17
# earn_rate >3 : 600452.SH 涪陵电力 10
# earn_rate >3 : 600466.SH 蓝光发展 12
# earn_rate >3 : 600476.SH 湘邮科技 15
# earn_rate >3 : 600478.SH 科力远 8
# earn_rate >3 : 600487.SH 亨通光电 8
# earn_rate >3 : 600489.SH 中金黄金 32
# earn_rate >3 : 600491.SH 龙元建设 23
# earn_rate >3 : 600496.SH 精工钢构 26
# earn_rate >3 : 600502.SH 安徽建工 13
# earn_rate >3 : 600505.SH 西昌电力 16
# earn_rate >3 : 600506.SH 香梨股份 15
# earn_rate >3 : 600509.SH 天富能源 19
# earn_rate >3 : 600510.SH 黑牡丹 12
# earn_rate >3 : 600517.SH 置信电气 19
# earn_rate >3 : 600521.SH 华海药业 11
# earn_rate >3 : 600522.SH 中天科技 21
# earn_rate >3 : 600523.SH 贵航股份 35
# earn_rate >3 : 600528.SH 中铁工业 26
# earn_rate >3 : 600538.SH 国发股份 15
# earn_rate >3 : 600540.SH 新赛股份 17
# earn_rate >3 : 600546.SH 山煤国际 16
# earn_rate >3 : 600547.SH 山东黄金 25
# earn_rate >3 : 600551.SH 时代出版 19
# earn_rate >3 : 600552.SH 凯盛科技 11
# earn_rate >3 : 600556.SH 天下秀 16
# earn_rate >3 : 600558.SH 大西洋 22
# earn_rate >3 : 600560.SH 金自天正 16
# earn_rate >3 : 600562.SH 国睿科技 23
# earn_rate >3 : 600565.SH 迪马股份 20
# earn_rate >3 : 600570.SH 恒生电子 15
# earn_rate >3 : 600577.SH 精达股份 17
# earn_rate >3 : 600584.SH 长电科技 21
# earn_rate >3 : 600596.SH 新安股份 19
# earn_rate >3 : 600602.SH 云赛智联 13
# earn_rate >3 : 600606.SH 绿地控股 26
# earn_rate >3 : 600617.SH 国新能源 14
# earn_rate >3 : 600621.SH 华鑫股份 19
# earn_rate >3 : 600629.SH 华建集团 26
# earn_rate >3 : 600635.SH 大众公用 25
# earn_rate >3 : 600643.SH 爱建集团 9
# earn_rate >3 : 600650.SH 锦江投资 22
# earn_rate >3 : 600651.SH 飞乐音响 28
# earn_rate >3 : 600661.SH 昂立教育 15
# earn_rate >3 : 600662.SH 强生控股 22
# earn_rate >3 : 600663.SH 陆家嘴 20
# earn_rate >3 : 600667.SH 太极实业 24
# earn_rate >3 : 600671.SH 天目药业 17
# earn_rate >3 : 600675.SH 中华企业 19
# earn_rate >3 : 600678.SH 四川金顶 21
# earn_rate >3 : 600684.SH 珠江实业 14
# earn_rate >3 : 600685.SH 中船防务 23
# earn_rate >3 : 600691.SH 阳煤化工 17
# earn_rate >3 : 600694.SH 大商股份 13
# earn_rate >3 : 600704.SH 物产中大 21
# earn_rate >3 : 600707.SH 彩虹股份 20
# earn_rate >3 : 600711.SH 盛屯矿业 17
# earn_rate >3 : 600714.SH 金瑞矿业 25
# earn_rate >3 : 600716.SH 凤凰股份 11
# earn_rate >3 : 600720.SH 祁连山 16
# earn_rate >3 : 600722.SH 金牛化工 18
# earn_rate >3 : 600735.SH 新华锦 15
# earn_rate >3 : 600737.SH 中粮糖业 28
# earn_rate >3 : 600740.SH 山西焦化 21
# earn_rate >3 : 600744.SH 华银电力 24
# earn_rate >3 : 600749.SH 西藏旅游 20
# earn_rate >3 : 600753.SH 东方银星 13
# earn_rate >3 : 600756.SH 浪潮软件 13
# earn_rate >3 : 600757.SH 长江传媒 13
# earn_rate >3 : 600758.SH 红阳能源 29
# earn_rate >3 : 600764.SH 中国海防 17
# earn_rate >3 : 600769.SH 祥龙电业 20
# earn_rate >3 : 600777.SH 新潮能源 12
# earn_rate >3 : 600778.SH 友好集团 19
# earn_rate >3 : 600779.SH 水井坊 20
# earn_rate >3 : 600783.SH 鲁信创投 25
# earn_rate >3 : 600784.SH 鲁银投资 18
# earn_rate >3 : 600785.SH 新华百货 16
# earn_rate >3 : 600789.SH 鲁抗医药 18
# earn_rate >3 : 600792.SH 云煤能源 20
# earn_rate >3 : 600793.SH 宜宾纸业 9
# earn_rate >3 : 600796.SH 钱江生化 13
# earn_rate >3 : 600797.SH 浙大网新 14
# earn_rate >3 : 600801.SH 华新水泥 12
# earn_rate >3 : 600803.SH 新奥股份 7
# earn_rate >3 : 600804.SH 鹏博士 18
# earn_rate >3 : 600805.SH 悦达投资 22
# earn_rate >3 : 600812.SH 华北制药 15
# earn_rate >3 : 600814.SH 杭州解百 13
# earn_rate >3 : 600829.SH 人民同泰 12
# earn_rate >3 : 600833.SH 第一医药 14
# earn_rate >3 : 600834.SH 申通地铁 18
# earn_rate >3 : 600844.SH 丹化科技 28
# earn_rate >3 : 600853.SH 龙建股份 16
# earn_rate >3 : 600864.SH 哈投股份 23
# earn_rate >3 : 600866.SH 星湖科技 14
# earn_rate >3 : 600869.SH 智慧能源 19
# earn_rate >3 : 600881.SH 亚泰集团 20
# earn_rate >3 : 600883.SH 博闻科技 21
# earn_rate >3 : 600884.SH 杉杉股份 12
# earn_rate >3 : 600885.SH 宏发股份 10
# earn_rate >3 : 600889.SH 南京化纤 18
# earn_rate >3 : 600890.SH 中房股份 5
# earn_rate >3 : 600893.SH 航发动力 16
# earn_rate >3 : 600958.SH 东方证券 15
# earn_rate >3 : 600962.SH 国投中鲁 27
# earn_rate >3 : 600965.SH 福成股份 10
# earn_rate >3 : 600966.SH 博汇纸业 24
# earn_rate >3 : 600976.SH 健民集团 17
# earn_rate >3 : 600978.SH 宜华生活 23
# earn_rate >3 : 600986.SH 科达股份 18
# earn_rate >3 : 601000.SH 唐山港 13
# earn_rate >3 : 601007.SH 金陵饭店 20
# earn_rate >3 : 601008.SH 连云港 25
# earn_rate >3 : 601011.SH 宝泰隆 27
# earn_rate >3 : 601021.SH 春秋航空 7
# earn_rate >3 : 601107.SH 四川成渝 19
# earn_rate >3 : 601117.SH 中国化学 21
# earn_rate >3 : 601118.SH 海南橡胶 29
# earn_rate >3 : 601126.SH 四方股份 15
# earn_rate >3 : 601127.SH 小康股份 6
# earn_rate >3 : 601128.SH 常熟银行 13
# earn_rate >3 : 601155.SH 新城控股 5
# earn_rate >3 : 601188.SH 龙江交通 16
# earn_rate >3 : 601198.SH 东兴证券 16
# earn_rate >3 : 601216.SH 君正集团 12
# earn_rate >3 : 601360.SH 三六零 17
# earn_rate >3 : 601515.SH 东风股份 11
# earn_rate >3 : 601600.SH 中国铝业 30
# earn_rate >3 : 601608.SH 中信重工 25
# earn_rate >3 : 601666.SH 平煤股份 35
# earn_rate >3 : 601699.SH 潞安环能 27
# earn_rate >3 : 601777.SH 力帆股份 20
# earn_rate >3 : 601811.SH 新华文轩 12
# earn_rate >3 : 601858.SH 中国科传 14
# earn_rate >3 : 601869.SH 长飞光纤 5
# earn_rate >3 : 601989.SH 中国重工 21
# earn_rate >3 : 603010.SH 万盛股份 4
# earn_rate >3 : 603012.SH 创力集团 14
# earn_rate >3 : 603017.SH 中衡设计 14
# earn_rate >3 : 603020.SH 爱普股份 13
# earn_rate >3 : 603025.SH 大豪科技 7
# earn_rate >3 : 603036.SH 如通股份 9
# earn_rate >3 : 603038.SH 华立股份 11
# earn_rate >3 : 603039.SH 泛微网络 3
# earn_rate >3 : 603058.SH 永吉股份 10
# earn_rate >3 : 603063.SH 禾望电气 12
# earn_rate >3 : 603128.SH 华贸物流 16
# 8         356   20170605  603999.SH   9.3601   9.5768   9.3601   9.5325
# 10        466   20171113  603999.SH   8.8486   9.0267   8.8288   8.9376
# 12        498   20171227  603999.SH   7.3342   8.0963   7.3144   7.6410
# 14        632   20180718  603999.SH   5.7013   5.8209   5.6813   5.7112
# 15        646   20180807  603999.SH   5.5418   5.7312   5.4920   5.6714
# 17        679   20180921  603999.SH   5.1730   5.2627   5.1630   5.2428
# 18        694   20181022  603999.SH   4.1663   4.3956   4.1364   4.3358
# 20        753   20190115  603999.SH   4.9238   5.0335   4.9238   5.0235
# 21        755   20190117  603999.SH   4.9836   5.1929   4.9338   5.0534
# 23        848   20190611  603999.SH   5.2627   5.5119   5.2627   5.4820
# 25       1041   20200325  603999.SH   6.0200   6.0600   5.9400   6.0000
# 26       1049   20200407  603999.SH   5.7800   5.8700   5.7400   5.8400
#
#     pre_close  change  pct_chg  ...  preday_vol  buy_price  target_price  \
# 0     13.6989  0.1513   1.1045  ...    65650.47    13.8502     14.265706
# 5     13.4736  0.1970   1.4621  ...    28597.36    13.6706     14.080718
# 7     10.7444  0.1133   1.0545  ...    19651.38    10.8577     11.183431
# 8      9.3601  0.1724   1.8419  ...    23672.65     9.5325      9.818475
# 10     8.8288  0.1088   1.2323  ...    16251.20     8.9376      9.205728
# 12     7.3639  0.2771   3.7630  ...    23446.80     7.6410      7.870230
# 14     5.7013  0.0099   0.1736  ...    27238.20     5.7112      5.882536
# 15     5.4920  0.1794   3.2666  ...    15474.40     5.6714      5.841542
# 17     5.1531  0.0897   1.7407  ...    18246.40     5.2428      5.400084
# 18     4.1464  0.1894   4.5678  ...    20039.26     4.3358      4.465874
# 20     4.9238  0.0997   2.0249  ...    31232.80     5.0235      5.174205
# 21     4.9637  0.0897   1.8071  ...    34808.76     5.0534      5.205002
# 23     5.3126  0.1694   3.1886  ...    29396.54     5.4820      5.646460
# 25     5.9200  0.0800   1.3514  ...    49014.80     6.0000      6.180000
# 26     5.6800  0.1600   2.8169  ...    33026.80     5.8400      6.015200
#
#     minimal_price  sell_price  hold_period               sell_reason  \
# 0       13.434694   13.441100          1.0  get minimal_price profit
# 5       13.260482   14.080718          1.0         get target profit
# 7       10.531969   10.286200          3.0  get minimal_price profit
# 8        9.246525    9.818475          2.0         get target profit
# 10       8.669472    8.650600          2.0  get minimal_price profit
# 12       7.411770    7.730100          4.0            get max period
# 14       5.539864    5.882536          1.0         get target profit
# 15       5.501258    5.741100          1.0  get minimal_price profit
# 17       5.085516    5.063400          3.0  get minimal_price profit
# 18       4.205726    4.465874          2.0         get target profit
# 20       4.872795    4.963700          1.0           get sell signal
# 21       4.901798    5.205002          1.0         get target profit
# 23       5.317540    5.646460          2.0         get target profit
# 25       5.820000    5.730000          3.0  get minimal_price profit
# 26       5.664800    6.015200          2.0         get target profit
#
#     earn_rate  earn_rate_per_day    win
# 0   -2.953748          -2.953748  False
# 5    3.000000           3.000000   True
# 7   -5.263546          -1.754515  False
# 8    3.000000           1.500000   True
# 10  -3.211153          -1.605576  False
# 12   1.166078           0.291519   True
# 14   3.000000           3.000000   True
# 15   1.228973           1.228973   True
# 17  -3.421836          -1.140612  False
# 18   3.000000           1.500000   True
# 20  -1.190405          -1.190405  False
# 21   3.000000           3.000000   True
# 23   3.000000           1.500000   True
# 25  -4.500000          -1.500000  False
# 26   3.000000           1.500000   True
#
# [15 rows x 89 columns]

# %%
# concat all df 
save_dir = "./output/select_by_3_percent/reesult_policy1/"

all_df = pd.DataFrame()
for i in range(len(pool_df)):  # len(pool_df)
    stock_code = pool_df.loc[i,"ts_code"]
    stock_name = pool_df.loc[i,"name"]
    try:
        select_df = pd.read_csv(save_dir+stock_code+".csv")
    except Exception as err:
        print(stock_code,stock_name,err)
    if len(select_df) > 1:
        if i == 0:
            all_df = select_df
        else:
            all_df = pd.concat([all_df,select_df])
all_df.to_csv("./output/select_by_3_percent/result_policy1.csv",index = False)

# %%
all_df = all_df.loc[all_df.earn_rate.values>-15,:]
all_df.sort_values(by = "trade_date",ascending = "True", inplace = True )
print(all_df.shape)
all_df.head(20)

# %%
all_df.columns.values
# Out:
# array(['pre_index', 'trade_date', 'ts_code', 'open', 'high', 'low',
#        'close', 'pre_close', 'change', 'pct_chg', 'vol', 'amount',
#        'turnover_rate', 'volume_ratio', 'trade_date_stamp', 'K', 'D', 'J',
#        'kdj_signal', 'sema', 'lema', 'dif', 'dea', 'macd', 'macd_signal',
#        'close_weekly', 'open_weekly', 'high_weekly', 'low_weekly',
#        'pre_close_weekly', 'change_weekly', 'pct_chg_weekly',
#        'vol_weekly', 'amount_weekly', 'K_weekly', 'D_weekly', 'J_weekly',
#        'kdj_signal_weekly', 'sema_weekly', 'lema_weekly', 'dif_weekly',
#        'dea_weekly', 'macd_weekly', 'macd_signal_weekly', 'close_monthly',
#        'open_monthly', 'high_monthly', 'low_monthly', 'pre_close_monthly',
#        'change_monthly', 'pct_chg_monthly', 'vol_monthly',
#        'amount_monthly', 'K_monthly', 'D_monthly', 'J_monthly',
#        'kdj_signal_monthly', 'sema_monthly', 'lema_monthly',
#        'dif_monthly', 'dea_monthly', 'macd_monthly',
#        'macd_signal_monthly', 'var', 'xx', 'xx1', 'yy', 'cross_signal',
#        'buy_signal', 'sell_signal', 'postday_open', 'postday_high',
#        'postday_low', 'postday_close', 'postday_vol', 'preday_open',
#        'preday_high', 'preday_low', 'preday_close', 'preday_vol',
#        'buy_price', 'target_price', 'minimal_price', 'sell_price',
#        'hold_period', 'sell_reason', 'earn_rate', 'earn_rate_per_day',
#        'win', 'postday_high_pst', 'high_pst', 'postday_open_pst',
#        'postday_close_pst'], dtype=object)

# %%
all_df["postday_high_pst"] = (all_df["postday_high"] /all_df["close"] -1)*100
all_df["high_pst"] = (all_df["high"] /all_df["pre_close"] -1)*100
all_df["postday_open_pst"] = (all_df["postday_open"] /all_df["close"] -1)*100
all_df["postday_close_pst"] = (all_df["postday_close"] /all_df["close"] -1)*100

# %%
def myScatter(map_df, col1 = "x", col2 = "y", color = None, save_dir = "./temp/"):
    # plot it
    cm=plt.cm.inferno  # ['viridis', 'plasma', 'inferno', 'magma', 'cividis']
    x = map_df[col1].values
    y = map_df[col2].values
    if not color:
        color = col1
    c = map_df[color].values
        
    plt.figure(figsize = (11,8))
    vmin = np.min(c)
    vmax = np.max(c)
    sc = plt.scatter(x, y, c=c, vmin=vmin, vmax=vmax, s=1, cmap=cm)
    plt.colorbar(sc)
    plt.xlabel(col1)
    plt.ylabel(col2)
    plt.savefig(save_dir+"scatter_"+col1+"_"+col2+"_"+color+".png")
    return 0

# %%
df = all_df.loc[all_df.earn_rate.values<-15,:]
df.head()

# %%
from mylab.pdplot.myplot import *
myScatter(all_df, col1 = "earn_rate", col2 = "D", color = "postday_high_pst", save_dir = "./temp/")
# Out:
# 0

# %%
all_df.postday_close_pst.mean()
# Out:
# 0.2214224584004815

# %%
all_df.earn_rate.hist(bins = 26)

# %%
np.mean(all_df.postday_high_pst.values>1)
# Out:
# 0.5516047228206037

# %%
all_df.postday_open_pst.hist(bins = 20)

# %%
all_df.postday_close_pst.hist(bins = 20)

# %%
data_df = all_df.groupby('hold_period').agg({"earn_rate":np.mean,"earn_rate_per_day":np.mean,"win":np.mean})
data_df
# Out:
#              earn_rate  earn_rate_per_day       win
# hold_period
# 1.0           0.295713           0.295713  0.540890
# 2.0           0.160851           0.080425  0.527089
# 3.0           0.115335           0.038445  0.522478
# 4.0           0.035486           0.008871  0.512170

# %%
# 
temp_df = all_df.loc[all_df.hold_period.values ==1,:] 
temp_df.shape
# Out:
# (6861, 93)

# %%
1+reduce(lambda x, y: x+y, data_df.earn_rate_per_day.values[:]/100)
# Out:
# 0.018684503612895642

# %%
from functools import reduce  
temp_df = all_df.loc[all_df.hold_period.values !=1,:] 
data_df = temp_df.groupby('trade_date').agg({"earn_rate":np.mean,"earn_rate_per_day":np.mean})
data_df["earn_rate_add1"] = (data_df["earn_rate_per_day"]+100)/100
# data_df["earn_rate_acc"]
a = [1+reduce(lambda x, y: x+y, data_df.earn_rate_per_day.values[:i+1]/100) for i in range(len(data_df))] # len(data_df)
b = [reduce(lambda x, y: x*y, data_df.earn_rate_add1.values[:i+1]) for i in range(len(data_df))] # len(data_df)
print(data_df.shape)
plt.figure(figsize=(16,5))
plt.plot(a)
plt.plot(b)
plt.legend(["add","mult"])
plt.show()
# Out:
# (1429, 3)

# %%
from mylab.stock.myread import getIndexDaily
index_df = getIndexDaily("399001.SZ", "20100303")
index_df["pct_chg_add1"] = (index_df["pct_chg"]+100)/100
b = [reduce(lambda x, y: x*y, index_df.pct_chg_add1.values[:i+1]) for i in range(len(index_df))] # len(data_df)
a = [1+reduce(lambda x, y: x+y, index_df.pct_chg.values[:i+1]/100) for i in range(len(index_df))] # len(data_df)
plt.figure(figsize=(16,5))
plt.plot(b)
plt.plot(a)

# %%
plt.plot(a)

# %%
index_df["pct_chg"].mean()
# Out:
# 0.007478196721311477

# %%
index_df = getIndexBasic()
index_df.head()
