# %%
import pandas as pd
import numpy as np
import tushare as ts
ts.set_token('29eaf3bcac23df4c6d025de157ab2d53beead3391fbe6e83b4ebcb6c')
pro = ts.pro_api()

import time
import matplotlib.pyplot as plt

# %%
SAVE_CSV = True
LOCAL = not True

GET_DAILY =  True
GET_WEEKLY = True
GET_MONTHLY = not True

# %%
from mylab.stock.myread import getStockBasic

# %%
#获取基础信息数据，包括股票代码、名称、上市日期、退市日期等
pool_df = getStockBasic(LOCAL = False,noSTKC = True, list_data = "20190101")
if SAVE_CSV:
    pool_df.to_csv("./data/stock/stock_basic_info.csv",index =False)
#print(pool.head())
print('获得上市股票总数：', len(pool_df)-1)
pool_df.head()
# Out:
# 获得上市股票总数： 2640
#      ts_code  symbol  name area industry market exchange list_status  \
# 0  000001.SZ  000001  平安银行   深圳       银行     主板     SZSE           L
# 1  000002.SZ  000002   万科A   深圳     全国地产     主板     SZSE           L
# 2  000004.SZ  000004  国农科技   深圳     生物制药     主板     SZSE           L
# 3  000005.SZ  000005  世纪星源   深圳     环境保护     主板     SZSE           L
# 4  000006.SZ  000006  深振业A   深圳     区域地产     主板     SZSE           L
#
#   list_date delist_date
# 0  19910403        None
# 1  19910129        None
# 2  19910114        None
# 3  19901210        None
# 4  19920427        None

# %%
daily_df = ts.pro_bar(ts_code='000001.SZ', asset='E', adj = "qfq", freq = "D",
                      start_date='20180101', end_date='20181011', factors = ["tor","vr"] )
daily_df.head()
# Out:
#   trade_date    ts_code   open   high    low  close  pre_close  change  \
# 0   20181011  000001.SZ  10.05  10.16   9.70   9.86      10.45   -0.59
# 1   20181010  000001.SZ  10.54  10.66  10.38  10.45      10.56   -0.11
# 2   20181009  000001.SZ  10.46  10.70  10.39  10.56      10.45    0.11
# 3   20181008  000001.SZ  10.70  10.79  10.45  10.45      11.05   -0.60
# 4   20180928  000001.SZ  10.78  11.27  10.78  11.05      10.74    0.31
#
#    pct_chg         vol       amount  turnover_rate  volume_ratio
# 0  -5.6459  1995143.83  1994186.611         1.1620          1.48
# 1  -1.0417   995200.08  1045666.180         0.5796          0.69
# 2   1.0526  1064084.26  1117946.550         0.6197          0.74
# 3  -5.4299  1686358.52  1793455.283         0.9821          1.19
# 4   2.8864  2110242.67  2331358.288         1.2290          1.89

# %%
# get daily data
start_date = "20100101"
end_date = "20200430"
save_dir = "./data/stock/daily/"

num_err = 0
if GET_DAILY:
    for i in range(len(pool_df)):
        stock_code = pool_df.loc[i,"ts_code"]
        stock_name = pool_df.loc[i,"name"]
        if True:# stock_code[0] == "0":
            if i%100 == 0:
                print('正在获取第%d家: %s,股票代码%s.' % (i+1,stock_name, stock_code))
            #接口限制访问200次/分钟，加一点微小的延时防止被ban
            time.sleep(0.333)
            df = df = ts.pro_bar(ts_code = stock_code, asset='E', adj = "qfq", freq = "D", factors = ["tor","vr"],
                                 start_date = start_date, end_date = end_date )
            try:
                df.to_csv(save_dir + stock_code + "-"+ stock_name + '.csv', index = False)
            except Exception as err:
                print("err: ",stock_code,stock_name,err)
                try:
                    df.to_csv(save_dir + stock_code + '.csv', index = False)
                except Exception as err:
                    print("err: ",stock_code,stock_name,err)
                    num_err = num_err +1
# Out:
# 正在获取第1家: 平安银行,股票代码000001.SZ.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-98ec44e572e0> in <module>
#      15             time.sleep(0.333)
#      16             df = df = ts.pro_bar(ts_code='000001.SZ', asset='E', adj = "qfq", freq = "D", factors = ["tor","vr"],
# ---> 17                                  start_date = start_date, end_date = end_date )
#      18             try:
#      19                 df.to_csv(save_dir + stock_code + "-"+ stock_name + '.csv', index = False)
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\tushare\pro\data_pro.py in pro_bar(ts_code, api, start_date, end_date, freq, asset, exchange, adj, ma, factors, adjfactor, offset, limit, contract_type, retry_count)
#     123                     data['pre_close'] = data['close'].shift(-1)
#     124                 if adj is not None:
# --> 125                     fcts = api.adj_factor(ts_code=ts_code, start_date=start_date, end_date=end_date)[['trade_date', 'adj_factor']]
#     126                     if fcts.shape[0] == 0:
#     127                         return None
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\tushare\pro\client.py in query(self, api_name, fields, **kwargs)
#      38         }
#      39
# ---> 40         res = requests.post(self.__http_url, json=req_params, timeout=self.__timeout, headers={'Connection':'close'})
#      41         result = json.loads(res.text)
#      42         if result['code'] != 0:
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# D:\Users\admin\Anaconda3\envs\py37-stock\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# get weekly data
startdate = '20010101'
enddate = '20200430'
save_dir = "./data/stock/weekly/"

if GET_WEEKLY:
    for i in range(len(pool_df)):
        stock_code = pool_df.loc[i,"ts_code"]
        stock_name = pool_df.loc[i,"name"]
        if True:# stock_code[0] == "0":
            if i%100 == 0:
                print('正在获取第%d家: %s,股票代码%s.' % (i+1,stock_name, stock_code))
            #接口限制访问200次/分钟，加一点微小的延时防止被ban
            time.sleep(0.333)
            df = df = ts.pro_bar(ts_code='000001.SZ', asset='E', adj = "qfq", freq = "D", factors = ["tor","vr"],
                                 start_date = start_date, end_date = end_date )
            try:
                df.to_csv(save_dir + stock_code + "-"+ stock_name + '.csv', index = False)
            except Exception as err:
                print("err: ",stock_code,stock_name,err)
                try:
                    df.to_csv(save_dir + stock_code + '.csv', index = False)
                except Exception as err:
                    print("err: ",stock_code,stock_name,err)
                    num_err = num_err +1
# Out:
# 正在获取第1家: 平安银行,股票代码000001.SZ.
# 正在获取第101家: *ST生物,股票代码000504.SZ.
# 正在获取第201家: 顺发恒业,股票代码000631.SZ.
# 正在获取第301家: 长江证券,股票代码000783.SZ.
# 正在获取第401家: *ST夏利,股票代码000927.SZ.
# 正在获取第501家: 美年健康,股票代码002044.SZ.
# 正在获取第601家: 荣盛发展,股票代码002146.SZ.
# 正在获取第701家: 北化股份,股票代码002246.SZ.
# 正在获取第801家: 高乐股份,股票代码002348.SZ.
# 正在获取第901家: 中原内配,股票代码002448.SZ.
# 正在获取第1001家: 千红制药,股票代码002550.SZ.
# 正在获取第1101家: 利君股份,股票代码002651.SZ.
# 正在获取第1201家: 南兴股份,股票代码002757.SZ.
# 正在获取第1301家: 钧达股份,股票代码002865.SZ.
# 正在获取第1401家: 博杰股份,股票代码002975.SZ.
# 正在获取第1501家: 科新机电,股票代码300092.SZ.
# 正在获取第1601家: 福安药业,股票代码300194.SZ.
# 正在获取第1701家: 三六五网,股票代码300295.SZ.
# 正在获取第1801家: 天和防务,股票代码300397.SZ.
# 正在获取第1901家: 富祥药业,股票代码300497.SZ.
# 正在获取第2001家: 瑞特股份,股票代码300600.SZ.
# 正在获取第2101家: 天宇股份,股票代码300702.SZ.
# 正在获取第2201家: 泰林生物,股票代码300813.SZ.
# 正在获取第2301家: 亚盛集团,股票代码600108.SH.
# 正在获取第2401家: 太龙药业,股票代码600222.SH.
# 正在获取第2501家: 中油工程,股票代码600339.SH.
# 正在获取第2601家: 中国动力,股票代码600482.SH.
# 正在获取第2701家: 光明乳业,股票代码600597.SH.
# 正在获取第2801家: 南宁百货,股票代码600712.SH.
# 正在获取第2901家: *ST劝业,股票代码600821.SH.
# 正在获取第3001家: 健民集团,股票代码600976.SH.
# 正在获取第3101家: 中国人保,股票代码601319.SH.
# 正在获取第3201家: 建设银行,股票代码601939.SH.
# 正在获取第3301家: 红蜻蜓,股票代码603116.SH.
# 正在获取第3401家: 我乐家居,股票代码603326.SH.
# 正在获取第3501家: 伯特利,股票代码603596.SH.
# 正在获取第3601家: 乾景园林,股票代码603778.SH.
# 正在获取第3701家: 醋化股份,股票代码603968.SH.
# 正在获取第3801家: 卓易信息,股票代码688258.SH.

# %%
# get monthly data
startdate = '20010101'
# enddate = '20200313'
save_dir = "./data/stock/monthly/"

if GET_MONTHLY:
    for i in range(len(pool_df)):
        stock_code = pool_df.loc[i,"ts_code"]
        stock_name = pool_df.loc[i,"name"]
        if i%100 == 0:
            print('正在获取第%d家: %s,股票代码%s.' % (i+1,stock_name, stock_code))
        #接口限制访问200次/分钟，加一点微小的延时防止被ban
        time.sleep(0.121)
        df = pro.monthly(ts_code = stock_code,startdate = startdate, enddate = enddate )

        try:
            df.to_csv(save_dir + stock_code + "-"+ stock_name + '.csv', index = False)
        except:
            try:
                df.to_csv(save_dir + stock_code + '.csv', index = False)
            except:
                pritn("err: ", stock_name)

# %%
# get hour data
startdate = '20010101'
# enddate = '20200313'
save_dir = "./data/stock/hour/"

if GET_MONTHLY:
    for i in range(len(pool_df)):
        stock_code = pool_df.loc[i,"ts_code"]
        stock_name = pool_df.loc[i,"name"]
        if i%100 == 0:
            print('正在获取第%d家: %s,股票代码%s.' % (i+1,stock_name, stock_code))
        #接口限制访问200次/分钟，加一点微小的延时防止被ban
        time.sleep(0.121)
        df =  ts.get_h_data(stock_code[:6]) #前复权
        try:
            df.to_csv(save_dir + stock_code + "-"+ stock_name + '.csv', index = False)
        except:
            try:
                df.to_csv(save_dir + stock_code + '.csv', index = False)
            except:
                pritn("err: ", stock_name)

# %%
df =  ts.get_h_data(stock_code[:6]) #前复权
df.head()
# Out:
# [Getting data:]#
# Empty DataFrame
# Columns: []
# Index: []
